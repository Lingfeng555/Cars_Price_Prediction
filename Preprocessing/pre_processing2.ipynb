# %% [markdown]
# # Imports
# We import some neccesary libraries and download some global scope data

# %%
import re
import os
import json
import pandas as pd
import ast
import nltk
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from dotenv import load_dotenv
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
import hashlib

nltk.download('stopwords')
load_dotenv()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Barak\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ### Set the absolute data folder path

# %%
current_folder = os.getcwd()
data_folder = os.path.join(current_folder, '../data')
data_folder = os.path.abspath(data_folder)

# %% [markdown]
# # Load the Datsets

# %%
def merge_csv_files_from_folder(folder_path):
    # Lista para almacenar los DataFrames
    df_list = []

    # Recorrer todos los archivos en la carpeta
    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):
            # Obtener la ruta completa del archivo
            file_path = os.path.join(folder_path, filename)
            
            # Leer el archivo CSV y agregarlo a la lista de DataFrames
            df = pd.read_csv(file_path)
            df_list.append(df)

    # Concatenar todos los DataFrames en uno solo
    if df_list:
        merged_df = pd.concat(df_list, ignore_index=True)
        return merged_df
    else:
        print("No se encontraron archivos CSV en la carpeta.")
        return pd.DataFrame()  

data = merge_csv_files_from_folder(f"{data_folder}/initial_data/data_processed/csv/")

#data["_id"] = data["car_id"]
#data.drop(columns="car_id", inplace=True)
# Out:
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\464140264.py:12: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\464140264.py:12: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\464140264.py:12: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\464140264.py:12: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\464140264.py:12: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\464140264.py:12: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\464140264.py:12: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path)

# %%
def convert_boolean(value):
    if value == "True":
        return True
    elif value == "False":
        return False
    else:
        return value
for colum in [40,41,44,45,46,47]: data.iloc[:, colum] = data.iloc[:, colum].apply(lambda x: convert_boolean(x))

# %%
def find_dirty_columns(prefix): return [col for col in data.columns if prefix in col]

# %% [markdown]
# # Cleaning Dirty Columns
#
# There are four columns that require cleaning: `^Confort_`, `^Acabado Interior_`, `^Acabado Exterior_`, and `^electricFeatures`. Colums will be processed until data becomes readable or data is feeded into the NLP. All columns should carry meaningful information. If a column contains a wide range of phrases it may be merged into a single column labeled as "description," which will allow the application of NLP techniques later.
#
# ### Followed guidelines for Cleaning:
#
# - **Singular and Plural Forms**:
#   If two columns represent the same feature, but one is the plural form of the other (e.g., `Confort_Luz` and `Confort_Luces`), the plural column has been discarted.
#
# - **Duplicate Column Names**:
#   If two columns share the same name, one of them can be discarted
#
# - **Numbered Columns**:
#   If multiple columns are part of a series ending with a number (e.g., `Confort_Dos`, `Confort_Uno`), they likely describe different aspects of a single feature. In this case, they will be merged into a single column.
#
# - **Relevance of Columns**:
#   Most of the dirty columns have names that describe the feature of their information, but some columns may be irrelevant.
#
#
# - **Nan and "no tiene"**:
#   Some data has an Nan and "no tiene", the first one means that we don't know the data but probably you can deduce that feature with other columns, specially in electrical features, and the second the car does nor have that feature.
#
#
# At the beginning of each section, you will find a printout of the columns that need to be cleaned.
#
# ---

# %% [markdown]
# ## Functions

# %%
def remove_duplicates(lista, elemento): return [x for x in lista if x != elemento]

def check_unique_values(column):
    ret = sorted(set(data[column].to_list()))
    print(f"Column: {column}")
    for x in ret: print(f'{x}: {data[column].to_list().count(x)}')
    print(f'NA: {data[column].to_list().count(None)}')

# %% [markdown]
# ## Clean Confort

# %%
confort_columns = find_dirty_columns("Confort")
for x in confort_columns: print(x)
# Out:
# Confort_Aire
# Confort_Apertura
# Confort_Aviso
# Confort_Banda
# Confort_Calefacción
# Confort_Cierre
# Confort_Compartimentos
# Confort_Control
# Confort_Dirección
# Confort_Dos
# Confort_Elevalunas
# Confort_Faros
# Confort_Indicador
# Confort_Inmovilizador
# Confort_Inmovilizador
#
# Confort_Intermitentes
# Confort_Lavafaros
# Confort_Lavafaros
#
# Confort_Limpiaparabrisas
# Confort_Llave
# Confort_Luces
# Confort_Luz
# Confort_Memoria
# Confort_Protección
# Confort_Regulación
# Confort_Sistema
# Confort_Tapa
# Confort_Tarjeta
# Confort_Techo
# Confort_Testigo
# Confort_Una
# Confort_Volante

# %%
def classify_ac_zones(val):
    cleaned_val = re.sub(r"[\[\]']", '', val).strip().lower()

    match cleaned_val:
        case val if 'bizona' in val or '2 zonas' in val:
            return 'BIZONA'
        case val if 'trizona' in val or '3 zonas' in val:
            return 'TRIZONA'
        case val if '4 zonas' in val:
            return 'TETRAZONA'
        case _:
            return 'MONOZONA' 
        
def classify_ac_type(val): 
    cleaned_val = re.sub(r"[\[\]']", '', val).strip().lower()
    match cleaned_val:
        case val if 'semi-auto' in val or 'semi-automático' in val or 'semi-automatico' in val:
            return 'SEMIAUTO'
        case val if 'automático' in val or 'auto' in val or 'automatico' in val:
            return 'AUTO'
        case val if 'manual' in val:
            return 'MANUAL'
        case val if 'no tiene' in val:
            return 'NO_TIENE'
        case _:
            return 'STANDARD'  
        
def extraer_numero_tcinturones(text):
    if 'un' in text: return 1
    elif 'dos' in text:return 2
    elif 'tres' in text:return 3
    elif 'cuatro' in text:return 4
    elif 'cinco' in text:return 5
    elif 'seis' in text:return 6
    elif 'siete' in text:return 7
    elif 'Testigo' in text: return 2
    else: return 0

# %%
#Confort Aire
data["AC_Zones"] = data["Confort_Aire"].apply(classify_ac_zones)
data["AC_Type"] = data["Confort_Aire"].apply(classify_ac_type) 

#Confort_Apertura
#El maletero se abre a distancia? (Mecanicamente o electricamente)
data["trunk_auto_open"] = data["Confort_Apertura"].apply(lambda x: False if 'no tiene' in x else True)

#Se podría quitar la verdad
data["BandaTintada"] = data["Confort_Banda"].apply(lambda x: False if 'no tiene' in x else True)

data["Calefacción_Trasera"] = data["Confort_Calefacción"].apply(lambda x: False if 'no tiene' in x else True)


data['Doble_Cierre'] = data['Confort_Cierre'].apply(lambda x: True if 'doble cierre' in x else False)
data['Movil_NFC'] = data['Confort_Cierre'].apply(lambda x: True if 'teléfono móvil' in x or 'NFC' in x else False)
data['Metodo_Apertura'] = data['Confort_Cierre'].apply(
   lambda x: 'Mando a distancia' if 'mando a distancia' in x else
              'Tarjeta/llave inteligente' if 'tarjeta/llave inteligente' in x else
              'Llave' if 'llave' in x else
              'Teléfono móvil' if 'teléfono móvil' in x else
              'Desconocido'
)


data["Control_Crucero"] = data["Confort_Control"].apply(lambda x: True if 'crucero' in x else False)
data["Control_Crucero_Adaptativo"] = data["Confort_Control"].apply(lambda x: True if 'adaptativo' in x else False)  
data["SensoresDistancia"] = data["Confort_Control"].apply(lambda x: True if 'distancia' in x else False)
data["StopGo"] = data["Confort_Control"].apply(lambda x: True if 'stop' in x else False)


data["Dirección_Asistida"] = data["Confort_Dirección"].apply(lambda x: True if 'dirección asistida' in x.lower() else False)
data["Dirección_Electrica"] = data["Confort_Dirección"].apply(lambda x: True if 'eléctrica' in x.lower() else False)
data["Endurecimiento_Progresivo"] = data["Confort_Dirección"].apply(lambda x: True if 'endurecimiento progresivo' in x.lower() else False)
data["Desmultiplicacion_Variable"] = data["Confort_Dirección"].apply(lambda x: True if 'desmultiplicación variable' in x.lower() else False)
data["Dirección_Electro_Hidraulica"] = data["Confort_Dirección"].apply(lambda x: True if 'electro-hidráulica' in x.lower() else False)


data["Elevalunas_Electricos"] = data["Confort_Elevalunas"].apply(lambda x: True if 'elevalunas eléctricos' in x.lower() else False)
data["Un_Solo_Toque"] = data["Confort_Elevalunas"].apply(lambda x: True if 'uno de ellos de un solo toque' in x.lower() or 'dos de ellos de un solo toque' in x.lower() else False)
data["Elevalunas_Traseros"] = data["Confort_Elevalunas"].apply(lambda x: True if 'traseros' in x.lower() else False)


data["Tipo_Faro"] = data["Confort_Faros"].apply(lambda x: 
    'LED' if 'led' in x.lower() else
    'Xenón' if 'xenón' in x.lower() else
    'Halógeno' if 'halógeno' in x.lower() else
    'Otro')
data["Luz_Larga"] = data["Confort_Faros"].apply(lambda x: True if 'luz larga' in x.lower() else False)
data["Faros_Dobles"] = data["Confort_Faros"].apply(lambda x: True if 'dobles' in x.lower() else False)


data["Indicador_Baja_Presion_Neumaticos"] = data["Confort_Indicador"].apply(lambda x: 
    True if 'baja presion' in x.lower() else False)
data["Visualizacion_Presion"] = data["Confort_Indicador"].apply(lambda x: 
    True if 'visualización de presión' in x.lower() else False)
data["Indicador_Consumo"] = data["Confort_Indicador"].apply(lambda x: 
    True if 'indicador de consumo' in x.lower() else False)


data["Inmovilizador"] = data["Confort_Inmovilizador"].apply(lambda x: 
    True if 'Inmovilizador' in x else False)


data["Intermitentes_Laterales"] = data["Confort_Intermitentes"].apply(lambda x:
    True if 'laterales' in x else False)


data["Lavafaros"] = data["Confort_Lavafaros"].apply(lambda x:
    True if 'Lavafaros' in x else False)


data["Sensor_Lluvia"] = data["Confort_Limpiaparabrisas"].apply(lambda x: 
    True if 'sensor de lluvia' in x.lower() else False)
data["Intermitencia_Automatica"] = data["Confort_Limpiaparabrisas"].apply(lambda x: 
    True if 'intermitencia automática' in x.lower() else False)


data["Luces_Lectura"] = data["Confort_Luces"].apply(lambda x: 
    True if 'luces de lectura' in x.lower() else False)
data["Luces_Antiniebla"] = data["Confort_Luces"].apply(lambda x: 
    True if 'luces antiniebla' in x.lower() else False)
data["Luces_Cortesía"] = data["Confort_Luces"].apply(lambda x: 
    True if 'luces de cortesía' in x.lower() else False)
data["Luces_Laterales"] = data["Confort_Luces"].apply(lambda x: 
    True if 'luces laterales maniobras' in x.lower() else False)


data["Memoria_Asientos"] = data["Confort_Memoria"].apply(lambda x: 
    True if 'posición' in x else False)


data["Techo_Electrico"] = data["Confort_Techo"].apply(lambda x: 
    True if 'eléctrico' in x.lower() else False)
data["Techo_Inclinable"] = data["Confort_Techo"].apply(lambda x: 
    True if 'inclinable' in x.lower() else False)
data["Techo_Deslizante"] = data["Confort_Techo"].apply(lambda x: 
    True if 'deslizante' in x.lower() else False)
data["Control_Remoto"] = data["Confort_Techo"].apply(lambda x: 
    True if 'control remoto' in x.lower() else False)

data["Testigo_Cinturones"] = data["Confort_Testigo"].apply(lambda x: 
    True if 'testigo de cinturones' in x.lower() else False)

data["Numero_Testigos"] = data["Confort_Testigo"].apply(extraer_numero_tcinturones)

def process_confort_volante(x):
    if x == "no tiene": return x
    else:
        if len(ast.literal_eval(x)) > 1: return ". ".join(ast.literal_eval(x))
        else: return ast.literal_eval(x)[0]

# Feed para el modelo NLP
data["Confort_Volante_Descripción"] = data["Confort_Volante"].apply(process_confort_volante)
# Out:
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\2626097604.py:93: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Techo_Electrico"] = data["Confort_Techo"].apply(lambda x:
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\2626097604.py:95: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Techo_Inclinable"] = data["Confort_Techo"].apply(lambda x:
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\2626097604.py:97: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Techo_Deslizante"] = data["Confort_Techo"].apply(lambda x:
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\2626097604.py:99: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Control_Remoto"] = data["Confort_Techo"].apply(lambda x:
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\2626097604.py:102: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Testigo_Cinturones"] = data["Confort_Testigo"].apply(lambda x:
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\2626097604.py:105: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Numero_Testigos"] = data["Confort_Testigo"].apply(extraer_numero_tcinturones)
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\2626097604.py:114: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["Confort_Volante_Descripción"] = data["Confort_Volante"].apply(process_confort_volante)

# %%
#Eliminar todas las columas con descripciones iniciales
for col in confort_columns: 
    data.drop(columns=col, inplace=True)

# %% [markdown]
# ## Clean Acabado Interior

# %%
acabado_interior_columns = find_dirty_columns("Acabado Interior")

# %%
acabado_interior_columns.remove("Acabado Interior_Asientos")
data.drop(columns="Acabado Interior_Asientos", inplace=True)

#for x in acabado_interior_columns: print(x)
#data[acabado_interior_columns]

# %%
# Definir funciones personalizadas para la conversión
def convert_sports_pedals(value):
    if value == "['Pedales deportivos']":
        return True
    elif value == 'no tiene':
        return False
    else:
        return None  # Por si hay otros valores

def convert_interior_clock(value):
    if value == "['Reloj analógico']":
        return 'analogico'
    elif value == "['Reloj digital']":
        return 'digital'
    elif value == "['Reloj']":
        return 'regular'
    elif value == "no tiene":
        return 'no tiene'
    else:
        return None  # Por si hay otros valores

# Aplicar las funciones a las columnas correspondientes
data["sports_pedals"] = data["Acabado Interior_Pedales"].apply(convert_sports_pedals)
data["interior_clock"] = data["Acabado Interior_Reloj"].apply(convert_interior_clock)

#check_unique_values("sports_pedals")
#check_unique_values("interior_clock")
# Out:
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\950979874.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["sports_pedals"] = data["Acabado Interior_Pedales"].apply(convert_sports_pedals)
# C:\Users\Barak\AppData\Local\Temp\ipykernel_8928\950979874.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data["interior_clock"] = data["Acabado Interior_Reloj"].apply(convert_interior_clock)

# %%
def process_arm_suppport_front(phrases: list) -> str:
    stop_words = set(stopwords.words('spanish'))
    stop_words.add(",")
    text = " # ".join(phrases)
    if not ('delantero' in text): return ("no tiene")
    text = [word for word in text.split() if word not in stop_words]
    if '#' in text: 
        ret = " ".join( text[ (text.index('delantero')+1):text.index('#')] )
        return "Tiene" if len(ret) == 0 else ret
    else: 
        ret = " ".join( text[(text.index('delantero')+1):len(text)] ) 
        return "Tiene" if len(ret) == 0 else ret

def process_arm_suppport_back(phrases: list) -> str:
    stop_words = set(stopwords.words('spanish'))
    stop_words.add(",")
    text = " # ".join(phrases)
    if not ('trasero' in text): return ("no tiene")

    text = [word for word in text.split() if word not in stop_words]

    ret = " ".join( text[(text.index('trasero')+1):len(text)] ) 
    return "Tiene" if len(ret) == 0 else ret 

arm_suppport_front = data["Acabado Interior_Apoyabrazos"].apply(lambda x: x if x == 'no tiene' else process_arm_suppport_front(eval(x)) )
arm_suppport_back = data["Acabado Interior_Apoyabrazos"].apply(lambda x: x if x == 'no tiene' else process_arm_suppport_back(eval(x)) )

data = pd.concat([data, arm_suppport_front.rename("arm_suppport_front"), arm_suppport_back.rename("arm_suppport_back")], axis=1)

check_unique_values("arm_suppport_front")
check_unique_values("arm_suppport_back")
# Out:
# Column: arm_suppport_front
# Tiene: 117241
# abatible: 98
# ajustable: 1
# caja integrada: 4238
# no tiene: 43859
# NA: 0
# Column: arm_suppport_back
# Tiene: 64993
# abatible: 5
# acceso maletero: 406
# ajustable: 2
# caja integrada: 1415
# caja integrada acceso maletero: 559
# no tiene: 98057
# NA: 0

# %%
def process_seat_description(phrases: list) -> str: return ". ".join(phrases)

data["seat_description"] = data["Acabado Interior_Asiento"].apply( lambda x: x if x == 'no tiene' else process_seat_description(eval(x)) )

# %%
data["Acabado Interior_Uno"] = data["Acabado Interior_Uno"].apply( lambda x: "['no tiene']" if x == 'no tiene' else x )
data["Acabado Interior_Dos"] = data["Acabado Interior_Dos"].apply( lambda x: "['no tiene']" if x == 'no tiene' else x )
data["Acabado Interior_Tres"] = data["Acabado Interior_Tres"].apply( lambda x: "['no tiene']" if x == 'no tiene' else x )
data["Acabado Interior_Reposacabezas"] = data["Acabado Interior_Reposacabezas"].apply( lambda x: "['no tiene']" if x == 'no tiene' else x )

data["Acabado Interior_Uno"] = data["Acabado Interior_Uno"].apply(ast.literal_eval)
data["Acabado Interior_Dos"] = data["Acabado Interior_Dos"].apply(ast.literal_eval)
data["Acabado Interior_Tres"] = data["Acabado Interior_Tres"].apply(ast.literal_eval)
data["Acabado Interior_Reposacabezas"] = data["Acabado Interior_Reposacabezas"].apply(ast.literal_eval)

# %%
data['head_supporter_description'] = data.apply(
    lambda row: ". ".join(
        remove_duplicates(row["Acabado Interior_Uno"] + row["Acabado Interior_Dos"] + row["Acabado Interior_Tres"] + row["Acabado Interior_Reposacabezas"], 'no tiene')
    ), 
    axis=1)
#check_unique_values("head_supporter")

data["transmissionTypeId"] = data["transmissionTypeId"].apply(lambda x: "Manual" if x == 2 else "Automatico")

for col in acabado_interior_columns: data.drop(columns= col, inplace=True)

# %%
print(len(data))
data = data[~data['airbag'].apply(lambda x: isinstance(x, float))]
print(len(data))
data["airbag_front"] = data["airbag"].apply(lambda x: True if "Airbag frontal" in x else False)
data["airbag_side_window"] = data["airbag"].apply(lambda x: True if "Airbag lateral de cortina" in x else False)
data["airbags_side"] = data["airbag"].apply(lambda x: True if "Airbags laterales" in x else False)

data.drop(columns= "airbag", inplace=True)
# Out:
# 165437
# 165416

# %%
data.loc[data["fuelType"] == "Eléctrico", "motor_description"] = "no tiene"

# %%
print(len(data))
data = data[~data['motor_description'].apply(lambda x: isinstance(x, float))]
print(len(data))

print(data["fuelType"].value_counts())
# Dictionary to convert Spanish words to numbers
word_to_number = {
    "uno": "1", "dos": "2", "tres": "3", "cuatro": "4", "cinco": "5",
    "seis": "6", "siete": "7", "ocho": "8", "nueve": "9", "diez": "10",
    "once": "11", "doce": "12", "trece": "13", "catorce": "14", "quince": "15",
    "dieciséis": "16", "diecisiete": "17", "dieciocho": "18", "diecinueve": "19", "veinte": "20", 
    "viente": "20", "vientecinco": "25", "vientecuatro": "24", "vienteuno": "21", "vientedos": "22", 
    "vientetres": "23", "vienteseis": "26", "vientesiete": "27", "vienteocho": "28", "vientenueve": "29", 
    "treinta": "30", 
       
}

# 1. Function to extract engine displacement in liters (e.g., "1.6 liters")
def extract_displacement_liters(phrase):
    match = re.search(r"(\d+,\d+) litros", phrase)
    return match.group(1) if match else "NA"

# 2. Function to extract engine displacement in cubic centimeters (e.g., "1.582 cc")
def extract_displacement_cc(phrase):
    match = re.search(r"\(\s*([\d,.]+)\s*cc\s*\)", phrase)
    return match.group(1) if match else "NA"

# 3. Function to extract the number of cylinders (e.g., "four cylinders" or "4 cylinders")
def extract_number_of_cylinders(phrase):
    match = re.search(r"(\w+|\d+) cilindros", phrase)
    if match:
        cylinders = match.group(1).lower()
        return word_to_number.get(cylinders, cylinders)  # Convert word to number if necessary
    return "NA"

# 4. Function to extract the number of valves per cylinder (e.g., "four valves per cylinder" or "4 valves")
def extract_valves_per_cylinder(phrase):
    match = re.search(r"(\w+|\d+) válvulas por cilindro", phrase)
    if match:
        valves = match.group(1).lower()
        return word_to_number.get(valves, valves)  # Convert word to number if necessary
    return "NA"

# 5. Function to extract cylinder diameter (e.g., "77.2 mm")
def extract_bore_diameter(phrase):
    match = re.search(r"(\d+,\d+)\s*mm de diámetro", phrase)
    return match.group(1) if match else "NA"

# 6. Function to extract stroke length (e.g., "84.5 mm")
def extract_stroke_length(phrase):
    match = re.search(r"(\d+,\d+)\s*mm de carrera", phrase)
    return match.group(1) if match else "NA"

# 7. Function to extract compression ratio (e.g., "17.3")
def extract_compression_ratio(phrase):
    match = re.search(r"relación de compresión:\s*(\d+,\d+)", phrase)
    return match.group(1) if match else "NA"


data["displacement_liters"] = data["motor_description"].apply(extract_displacement_liters)
#print(data["displacement_liters"].value_counts())

data["displacement_cc"] = data["motor_description"].apply(extract_displacement_cc)
#print(data["displacement_cc"].value_counts())

data["number_of_cylinders"] = data["motor_description"].apply(extract_number_of_cylinders)
#print(data["number_of_cylinders"].value_counts())

data["valves_per_cylinder"] = data["motor_description"].apply(extract_valves_per_cylinder)
#print(data["valves_per_cylinder"].value_counts())

data["bore_diameter"] = data["motor_description"].apply(extract_bore_diameter)
#print(data["bore_diameter"].value_counts())

data["stroke_length"] = data["motor_description"].apply(extract_stroke_length)
#print(data["stroke_length"].value_counts())

data["compression_ratio"] = data["motor_description"].apply(extract_compression_ratio)
#print(data["compression_ratio"].value_counts())
# Out:
# 165416
# 165416
# fuelType
# Diésel                71962
# Gasolina              57496
# Híbrido               20099
# Híbrido enchufable     7955
# Eléctrico              6612
# Gas licuado (GLP)       930
# Gas natural (CNG)       360
# Name: count, dtype: int64

# %%
print(len(data))
data = data[~data['speakers'].apply(lambda x: isinstance(x, float))]
print(len(data))
data["speakers"] = data["speakers"].apply(lambda x: word_to_number[x.lower()] if x != "0" else 0)
# Out:
# 165416
# 165141

# %% [markdown]
# ## Clean Acabado Exterior

# %%
stopw = frozenset(stopwords.words('spanish')) | {","}

def cleanTry(phrases: list) -> str:
    if not phrases:
        return "no tiene"
    
    text = phrases
    
    text = [word for word in text.split() if word.lower() not in stopw]

    return "no tiene" if len(text) == 0 else " ".join(text)

def extract_diameter(text):
    match = re.search(r'(\d+(?:,\d+)?)\s*pulgadas\s*diámetro', text)
    if match:
        return (float(match.group(1).replace(',', '.'))*2.54)
    else:
        return "no tiene"  
    
def clean_acabado(cell):
    cell_cleaned = re.sub(r"[\[\]']", '', cell)
    cell_cleaned = cell_cleaned.strip().lower()
    cell_cleaned = re.sub(r'\s+', ' ', cell_cleaned)
    return cell_cleaned

# %%
data.drop(columns=["Acabado Exterior_Maletero","Acabado Exterior_Pasos","Acabado Exterior_Maletero","Acabado Exterior_Defensa","Acabado Exterior_Guardabarros"], inplace=True)

# %%
acabado_exterior_columns = find_dirty_columns("Acabado Exterior")

data[acabado_exterior_columns] = data[acabado_exterior_columns].apply(lambda col: col.apply(lambda x: clean_acabado(x) if x != 'no tiene' else x))

data[acabado_exterior_columns] = data[acabado_exterior_columns].apply(lambda col: col.apply(lambda x: cleanTry(x) if x != 'no tiene' else x))

data["Llantas_Diametro_cm"] = data["Acabado Exterior_Llantas"].apply(lambda x: extract_diameter(x))

acabado_exterior_columns.append("Llantas_Diametro_cm")



for x in acabado_exterior_columns:
    
    #print(x)
    print(data[x].nbytes)
    print("Descripcion --------------------------")
    print(data[x].astype('category').nbytes)
    #print(data[x].describe())
    #print("Counts--------------------------------")
    #print(data[x].value_counts())
    #print("CleanTry------------------------------")
# Out:
# 1321128
# Descripcion --------------------------
# 165429
# 1321128
# Descripcion --------------------------
# 165245
# 1321128
# Descripcion --------------------------
# 165157
# 1321128
# Descripcion --------------------------
# 344706
# 1321128
# Descripcion --------------------------
# 165285
# 1321128
# Descripcion --------------------------
# 368882
# 1321128
# Descripcion --------------------------
# 165421
# 1321128
# Descripcion --------------------------
# 331538
# 1321128
# Descripcion --------------------------
# 333874
# 1321128
# Descripcion --------------------------
# 165565
# 1321128
# Descripcion --------------------------
# 165253

# %% [markdown]
# ## Electronic Features

# %%
print(len(data))
data = data[~data['fuelType'].apply(lambda x: isinstance(x, float))]
print(len(data))


check_unique_values("fuelType")

electronic_columns = find_dirty_columns("electric")
#for x in electronic_columns: print(x)
# Out:
# 165141
# 165139
# Column: fuelType
# Diésel: 71808
# Eléctrico: 6591
# Gas licuado (GLP): 930
# Gas natural (CNG): 360
# Gasolina: 57396
# Híbrido: 20099
# Híbrido enchufable: 7955
# NA: 0

# %%
# Seleccionar las columnas específicas del dataset
# Mostrar las primeras filas de esas columnas
data[electronic_columns].head()
# Out:
#   electricFeatures.powerSource.batteryType  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                           iones de litio
# 4                                      NaN
#
#    electricFeatures.powerSource.batteryVoltage.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              352.0
# 4                                                NaN
#
#   electricFeatures.powerSource.batteryVoltage.unit  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                                V
# 4                                              NaN
#
#    electricFeatures.powerSource.maximumBatteryKWH.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              42.24
# 4                                                NaN
#
#   electricFeatures.powerSource.maximumBatteryKWH.unit  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                kWh
# 4                                                NaN
#
#    electricFeatures.power.maxPower.value electricFeatures.power.maxPower.unit  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                  118.0                                   CV
# 4                                    NaN                                  NaN
#
#   electricFeatures.chargingInformation.standardMode.scenario  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                             modo 2
# 4                                                NaN
#
#    electricFeatures.chargingInformation.standardMode.duration.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                              915.0
# 4                                                NaN
#
#   electricFeatures.chargingInformation.standardMode.duration.unit  ...  \
# 0                                                NaN               ...
# 1                                                NaN               ...
# 2                                                NaN               ...
# 3                                            minutos               ...
# 4                                                NaN               ...
#
#    electricFeatures.chargingInformation.standardMode.chargeEnd.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   electricFeatures.chargingInformation.standardMode.chargeEnd.unit  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   electricFeatures.chargingInformation.fastMode.chargeStart.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    electricFeatures.chargingInformation.fastMode.chargeStart.unit  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   electricFeatures.chargingInformation.fastMode.voltage.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    electricFeatures.chargingInformation.fastMode.voltage.unit  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   electricFeatures.chargingInformation.standardMode.maxKW.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    electricFeatures.chargingInformation.standardMode.maxKW.unit  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   electricFeatures.chargingInformation.fastMode.amps.value  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   electricFeatures.chargingInformation.fastMode.amps.unit
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 42 columns]

# %%
def clean_and_transform_data(df):
    df_cleaned = df.copy()

    # Lista de columnas que queremos eliminar
    columns_to_drop = [
        'electricFeatures.chargingInformation.standardMode.chargeEnd.value',
        'electricFeatures.chargingInformation.standardMode.chargeEnd.unit',
        'electricFeatures.powerSource.batteryVoltage.value',
        'electricFeatures.powerSource.batteryVoltage.unit',
        'electricFeatures.powerSource.maximumBatteryKWH.value',
        'electricFeatures.powerSource.maximumBatteryKWH.unit',
        'electricFeatures.power.maxPower.value',
        'electricFeatures.power.maxPower.unit',
        'electricFeatures.chargingInformation.standardMode.duration.value',
        'electricFeatures.chargingInformation.standardMode.duration.unit',
        'electricFeatures.chargingInformation.fastMode.duration.value',
        'electricFeatures.chargingInformation.fastMode.duration.unit',
        'electricFeatures.chargingInformation.fastMode.maxKW.value',
        'electricFeatures.chargingInformation.fastMode.maxKW.unit',
        'electricFeatures.chargingInformation.fastMode.chargeEnd.value',
        'electricFeatures.chargingInformation.fastMode.chargeEnd.unit',
        'electricFeatures.combinedConsumption.value',
        'electricFeatures.combinedConsumption.unit',
        'electricFeatures.powerSource.onboardCharger.value',
        'electricFeatures.powerSource.onboardCharger.unit',
        'electricFeatures.chargingInformation.standardMode.voltage.value',
        'electricFeatures.chargingInformation.standardMode.voltage.unit',
        'electricFeatures.chargingInformation.standardMode.chargeStart.value',
        'electricFeatures.chargingInformation.standardMode.chargeStart.unit',
        'electricFeatures.chargingInformation.fastMode.chargeStart.value',
        'electricFeatures.chargingInformation.fastMode.chargeStart.unit',
        'electricFeatures.chargingInformation.fastMode.voltage.value',
        'electricFeatures.chargingInformation.fastMode.voltage.unit',
        'electricFeatures.chargingInformation.standardMode.maxKW.value',
        'electricFeatures.chargingInformation.standardMode.maxKW.unit',
        'electricFeatures.chargingInformation.fastMode.amps.value',
        'electricFeatures.chargingInformation.fastMode.amps.unit',
        'electricFeatures.chargingInformation.standardMode.amps.value',
        'electricFeatures.chargingInformation.standardMode.amps.unit',
        'electricFeatures.range.value',
        'electricFeatures.range.unit',
        'electricFeatures.chargingInformation.standardMode.scenario',
        'electricFeatures.chargingInformation.fastMode.scenario'


    ]

    # Combinación de columnas 'value' y 'unit' evitando NaN
    # Battery Voltage
    if 'electricFeatures.powerSource.batteryVoltage.value' in df_cleaned.columns and \
       'electricFeatures.powerSource.batteryVoltage.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.powerSource.batteryVoltage.value'].notna() & \
               df_cleaned['electricFeatures.powerSource.batteryVoltage.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.batteryVoltage'] = df_cleaned['electricFeatures.powerSource.batteryVoltage.value'].astype(str) + ' ' + df_cleaned['electricFeatures.powerSource.batteryVoltage.unit']

    if 'electricFeatures.range.value' in df_cleaned.columns and \
       'electricFeatures.range.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.range.value'].notna() & \
               df_cleaned['electricFeatures.range.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.range'] = df_cleaned['electricFeatures.range.value'].astype(str) + ' ' + df_cleaned['electricFeatures.range.unit']

    # Maximum Battery KWH
    if 'electricFeatures.powerSource.maximumBatteryKWH.value' in df_cleaned.columns and \
       'electricFeatures.powerSource.maximumBatteryKWH.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.powerSource.maximumBatteryKWH.value'].notna() & \
               df_cleaned['electricFeatures.powerSource.maximumBatteryKWH.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.maximumBatteryKWH'] = df_cleaned['electricFeatures.powerSource.maximumBatteryKWH.value'].astype(str) + ' ' + df_cleaned['electricFeatures.powerSource.maximumBatteryKWH.unit']

    # Power Max
    if 'electricFeatures.power.maxPower.value' in df_cleaned.columns and \
       'electricFeatures.power.maxPower.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.power.maxPower.value'].notna() & \
               df_cleaned['electricFeatures.power.maxPower.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.maxPower'] = df_cleaned['electricFeatures.power.maxPower.value'].astype(str) + ' ' + df_cleaned['electricFeatures.power.maxPower.unit']

    # Standard Mode Duration
    if 'electricFeatures.chargingInformation.standardMode.duration.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.standardMode.duration.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.standardMode.duration.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.standardMode.duration.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.standardChargeDuration'] = df_cleaned['electricFeatures.chargingInformation.standardMode.duration.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.standardMode.duration.unit']

    # Fast Mode Duration
    if 'electricFeatures.chargingInformation.fastMode.duration.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.fastMode.duration.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.fastMode.duration.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.fastMode.duration.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.fastChargeDuration'] = df_cleaned['electricFeatures.chargingInformation.fastMode.duration.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.fastMode.duration.unit']

    # Fast Mode Max KW
    if 'electricFeatures.chargingInformation.fastMode.maxKW.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.fastMode.maxKW.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.fastMode.maxKW.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.fastMode.maxKW.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.fastMaxKW'] = df_cleaned['electricFeatures.chargingInformation.fastMode.maxKW.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.fastMode.maxKW.unit']

    # Fast Mode Charge End
    if 'electricFeatures.chargingInformation.fastMode.chargeEnd.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.fastMode.chargeEnd.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.fastMode.chargeEnd.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.fastMode.chargeEnd.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.fastChargeEnd'] = df_cleaned['electricFeatures.chargingInformation.fastMode.chargeEnd.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.fastMode.chargeEnd.unit']

    # Combined Consumption
    if 'electricFeatures.combinedConsumption.value' in df_cleaned.columns and \
       'electricFeatures.combinedConsumption.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.combinedConsumption.value'].notna() & \
               df_cleaned['electricFeatures.combinedConsumption.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.combinedConsumption'] = df_cleaned['electricFeatures.combinedConsumption.value'].astype(str) + ' ' + df_cleaned['electricFeatures.combinedConsumption.unit']

    # Onboard Charger
    if 'electricFeatures.powerSource.onboardCharger.value' in df_cleaned.columns and \
       'electricFeatures.powerSource.onboardCharger.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.powerSource.onboardCharger.value'].notna() & \
               df_cleaned['electricFeatures.powerSource.onboardCharger.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.onboardCharger'] = df_cleaned['electricFeatures.powerSource.onboardCharger.value'].astype(str) + ' ' + df_cleaned['electricFeatures.powerSource.onboardCharger.unit']

    # Standard Mode Voltage
    if 'electricFeatures.chargingInformation.standardMode.voltage.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.standardMode.voltage.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.standardMode.voltage.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.standardMode.voltage.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.standardModeVoltage'] = df_cleaned['electricFeatures.chargingInformation.standardMode.voltage.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.standardMode.voltage.unit']

    # Standard Mode Charge Start
    if 'electricFeatures.chargingInformation.standardMode.chargeStart.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.standardMode.chargeStart.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.standardMode.chargeStart.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.standardMode.chargeStart.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.standardModeChargeStart'] = df_cleaned['electricFeatures.chargingInformation.standardMode.chargeStart.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.standardMode.chargeStart.unit']

    # Standard Mode Charge End
    if 'electricFeatures.chargingInformation.standardMode.chargeEnd.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.standardMode.chargeEnd.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.standardMode.chargeEnd.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.standardMode.chargeEnd.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.standardModeChargeEnd'] = df_cleaned['electricFeatures.chargingInformation.standardMode.chargeEnd.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.standardMode.chargeEnd.unit']

    # Fast Mode Charge Start
    if 'electricFeatures.chargingInformation.fastMode.chargeStart.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.fastMode.chargeStart.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.fastMode.chargeStart.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.fastMode.chargeStart.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.fastModeChargeStart'] = df_cleaned['electricFeatures.chargingInformation.fastMode.chargeStart.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.fastMode.chargeStart.unit']

    # Fast Mode Voltage
    if 'electricFeatures.chargingInformation.fastMode.voltage.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.fastMode.voltage.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.fastMode.voltage.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.fastMode.voltage.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.fastModeVoltage'] = df_cleaned['electricFeatures.chargingInformation.fastMode.voltage.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.fastMode.voltage.unit']

    # Standard Mode Max KW
    if 'electricFeatures.chargingInformation.standardMode.maxKW.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.standardMode.maxKW.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.standardMode.maxKW.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.standardMode.maxKW.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.standardModeMaxKW'] = df_cleaned['electricFeatures.chargingInformation.standardMode.maxKW.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.standardMode.maxKW.unit']

    # Fast Mode Amps
    if 'electricFeatures.chargingInformation.fastMode.amps.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.fastMode.amps.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.fastMode.amps.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.fastMode.amps.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.fastModeAmps'] = df_cleaned['electricFeatures.chargingInformation.fastMode.amps.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.fastMode.amps.unit']


    if 'electricFeatures.chargingInformation.standardMode.amps.value' in df_cleaned.columns and \
       'electricFeatures.chargingInformation.standardMode.amps.unit' in df_cleaned.columns:
        mask = df_cleaned['electricFeatures.chargingInformation.standardMode.amps.value'].notna() & \
               df_cleaned['electricFeatures.chargingInformation.standardMode.amps.unit'].notna()
        df_cleaned.loc[mask, 'electricFeatures.chargingInformation.standardMode'] = df_cleaned['electricFeatures.chargingInformation.standardMode.amps.value'].astype(str) + ' ' + df_cleaned['electricFeatures.chargingInformation.standardMode.amps.unit']

    # Eliminar solo las columnas que existen en el dataset
    columns_to_drop = [col for col in columns_to_drop if col in df_cleaned.columns]
    df_cleaned.drop(columns=columns_to_drop, inplace=True)

    return df_cleaned

# Limpiar el dataset
data = clean_and_transform_data(data)

# Mostrar una vista previa de los primeros registros
data.head()
# Out:
#     price       km    year         color  cubicCapacity    brand   model  \
# 0   10600  99700.0  2006.0         Negro         1798.0    MAZDA    MX-5
# 1   12450  91924.0  2015.0  Rojo (*TLV*)         1362.0     OPEL  Cabrio
# 2  134900  62000.0  2015.0         Negro         3800.0  PORSCHE     911
# 3   27500  13500.0  2022.0          Rosa            NaN     FIAT     500
# 4   27990  13559.0  2023.0        Blanco         1498.0    CUPRA    León
#
#                        version        car_id   fuelType  ...  \
# 0                   Active 1.8  4.657992e+13   Gasolina  ...
# 1          1.4 T SS Excellence  7.185223e+14   Gasolina  ...
# 2                  Turbo Coupe  7.197881e+14   Gasolina  ...
# 3  laPrima 31 320km 85kW 118CV  8.226220e+14  Eléctrico  ...
# 4     1.5 eTSI 110kW 150CV DSG  8.341591e+14    Híbrido  ...
#
#   electricFeatures.combinedConsumption electricFeatures.onboardCharger  \
# 0                                  NaN                             NaN
# 1                                  NaN                             NaN
# 2                                  NaN                             NaN
# 3                       14.6 kWh/100km                             NaN
# 4                                  NaN                             NaN
#
#    electricFeatures.standardModeVoltage  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    electricFeatures.standardModeChargeStart  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    electricFeatures.standardModeChargeEnd  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   electricFeatures.fastModeChargeStart electricFeatures.fastModeVoltage  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#    electricFeatures.standardModeMaxKW  electricFeatures.fastModeAmps  \
# 0                                 NaN                            NaN
# 1                                 NaN                            NaN
# 2                                 NaN                            NaN
# 3                                 NaN                            NaN
# 4                                 NaN                            NaN
#
#    electricFeatures.chargingInformation.standardMode
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                             13.0 A
# 4                                                NaN
#
# [5 rows x 148 columns]

# %%
def ver_columna(df, nombre_columna):
    if nombre_columna in df.columns:
        print(df[nombre_columna].head())  # Mostrar las primeras filas de la columna
    else:
        print(f"La columna '{nombre_columna}' no existe en el DataFrame.")

# Ejemplo de uso
ver_columna(data, 'electricFeatures.chargingInformation.standardMode.chargeEnd.value')
# Out:
# La columna 'electricFeatures.chargingInformation.standardMode.chargeEnd.value' no existe en el DataFrame.

# %%
def find_dirty_columns2(prefix): return [col for col in data.columns if prefix in col]

# %%
def count_nan_and_non_nan(df, column_name):
    if column_name in df.columns:
        # Contar valores no nulos
        non_nan_count = df[column_name].notna().sum()
        # Contar valores NaN
        nan_count = df[column_name].isna().sum()
        print(f"Columna: {column_name}")
        print(f"Valores normales: {non_nan_count}")
        print(f"Valores NaN: {nan_count}")
    else:
        print(f"La columna '{column_name}' no existe en el DataFrame.")
        
# Usar la función con el DataFrame y la columna que desees
column_to_check = 'electricFeatures.chargingInformation.standardMode.chargeEnd.value'  # Cambia por la columna que desees
count_nan_and_non_nan(data, column_to_check)
# Out:
# La columna 'electricFeatures.chargingInformation.standardMode.chargeEnd.value' no existe en el DataFrame.

# %%
electronic_columns2 = find_dirty_columns2("electric")
#for x in electronic_columns2: print(x)
# Mostrar las primeras filas de esas columnas
data[electronic_columns2].head()
# Out:
#   electricFeatures.powerSource.batteryType  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                           iones de litio
# 4                                      NaN
#
#                     electricFeatures.motorType  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3  ['motor síncrono de imanes permanentes CA']
# 4                                          NaN
#
#   electricFeatures.chargingConnector  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3  ['CCS(Combo)', 'Tipo 2 Mennekes']
# 4                                NaN
#
#   electricFeatures.combinedConsumption.testType  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3          BEV/HEV consumo de energía eléctrica
# 4                                           NaN
#
#   electricFeatures.batteryVoltage electricFeatures.range  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             NaN                    NaN
# 3                         352.0 V               305.0 KM
# 4                             NaN                    NaN
#
#   electricFeatures.maximumBatteryKWH electricFeatures.maxPower  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                          42.24 kWh                  118.0 CV
# 4                                NaN                       NaN
#
#   electricFeatures.standardChargeDuration electricFeatures.fastChargeDuration  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                     NaN                                 NaN
# 3                           915.0 minutos                        34.0 minutos
# 4                                     NaN                                 NaN
#
#    ... electricFeatures.combinedConsumption electricFeatures.onboardCharger  \
# 0  ...                                  NaN                             NaN
# 1  ...                                  NaN                             NaN
# 2  ...                                  NaN                             NaN
# 3  ...                       14.6 kWh/100km                             NaN
# 4  ...                                  NaN                             NaN
#
#   electricFeatures.standardModeVoltage  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   electricFeatures.standardModeChargeStart  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   electricFeatures.standardModeChargeEnd electricFeatures.fastModeChargeStart  \
# 0                                    NaN                                  NaN
# 1                                    NaN                                  NaN
# 2                                    NaN                                  NaN
# 3                                    NaN                                  NaN
# 4                                    NaN                                  NaN
#
#   electricFeatures.fastModeVoltage electricFeatures.standardModeMaxKW  \
# 0                              NaN                                NaN
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#   electricFeatures.fastModeAmps  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#   electricFeatures.chargingInformation.standardMode
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                            13.0 A
# 4                                               NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# # Save file

# %%
data = data.rename(columns={'parking_sensors': 'parking_sensors_description'})
data = data.rename(columns={'Acabado Exterior_Llantas': 'Exterior_Llantas_description'})
data = data.rename(columns={'Acabado Exterior_Molduras': 'Exterior_Molduras_description'})
data = data.rename(columns={'Acabado Exterior_Neumáticos': 'Exterior_Neumáticos_description'})
data = data.rename(columns={'Acabado Exterior_Puerta': 'Exterior_Puerta_description'})
data = data.rename(columns={'Acabado Exterior_Retrovisor': 'Exterior_Retrovisor_description'})
data = data.rename(columns={'Confort_Volante_Descripción': 'Confort_Volante_description'})

# %%
max_file_size = 100 * 1024 * 1024
def split_dataframe_to_csv(df, max_file_size, output_folder ,base_filename):
    file_index = 1
    chunk_size = len(df) // 7 
    while chunk_size > 0:
        start_row = 0
        while start_row < len(df):
            end_row = start_row + chunk_size
            chunk = df.iloc[start_row:end_row]
            filename = f"{output_folder}/{base_filename}_part{file_index}.csv"
            chunk.to_csv(filename, index=False)
            if os.path.getsize(filename) > max_file_size:
                chunk_size //= 2
                os.remove(filename)
            else:
                start_row = end_row
                file_index += 1

        if start_row >= len(df):
            break

train_set, test_set = train_test_split(data, test_size=0.3, random_state=42, stratify=data['fuelType'])

print("Original fuelType distribution:\n", data['fuelType'].value_counts(normalize=True))
print("\nTrain set fuelType distribution:\n", train_set['fuelType'].value_counts(normalize=True))
print("\nTest set fuelType distribution:\n", test_set['fuelType'].value_counts(normalize=True))
#data_folder = "../data/"
split_dataframe_to_csv(data, max_file_size, f"{data_folder}/final_data/original", "original")
split_dataframe_to_csv(train_set, max_file_size, f"{data_folder}/final_data/train", "train")
split_dataframe_to_csv(test_set, max_file_size, f"{data_folder}/final_data/test", "test")
# Out:
# Original fuelType distribution:
#  fuelType
# Diésel                0.434834
# Gasolina              0.347562
# Híbrido               0.121710
# Híbrido enchufable    0.048172
# Eléctrico             0.039912
# Gas licuado (GLP)     0.005632
# Gas natural (CNG)     0.002180
# Name: proportion, dtype: float64
#
# Train set fuelType distribution:
#  fuelType
# Diésel                0.434830
# Gasolina              0.347561
# Híbrido               0.121707
# Híbrido enchufable    0.048176
# Eléctrico             0.039915
# Gas licuado (GLP)     0.005632
# Gas natural (CNG)     0.002180
# Name: proportion, dtype: float64
#
# Test set fuelType distribution:
#  fuelType
# Diésel                0.434843
# Gasolina              0.347564
# Híbrido               0.121715
# Híbrido enchufable    0.048161
# Eléctrico             0.039906
# Gas licuado (GLP)     0.005632
# Gas natural (CNG)     0.002180
# Name: proportion, dtype: float64

# %% [markdown]
# ### Insert data into MongoDB to be used later in REST API

# %%
db_uri = os.getenv('MONGO_DB_URI')
data_dict = data.to_dict(orient='records')

# Create a new client and connect to the server
client = MongoClient(db_uri, server_api=ServerApi('1'))
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
    
DEPLOY = False


if DEPLOY:
    # Create a new database
    db = client.db
    # Create a new collection
    collection = db.cars
    
    for i, car in enumerate(data_dict, 1):
        #key_components = f"{car['brand']}_{car['model']}_{car['year']}_{car['km']}_{car['price']}_{car['color']}_{car['province']}_{car['version']}"
        #unique_id = hashlib.md5(key_components.encode()).hexdigest()
        car["_id"] = car["idx"]
        car.pop("idx")  
        collection.insert_one(car)
        if i % 100 == 0:
            print(f"Number of cars inserted: {i}")
# Out:
# Pinged your deployment. You successfully connected to MongoDB!
# Number of cars inserted: 100
# Number of cars inserted: 200
# Number of cars inserted: 300
# Number of cars inserted: 400
# Number of cars inserted: 500
# Number of cars inserted: 600
# Number of cars inserted: 700
# Number of cars inserted: 800
# Number of cars inserted: 900
# Number of cars inserted: 1000
# Number of cars inserted: 1100
# Number of cars inserted: 1200
# Number of cars inserted: 1300
# Number of cars inserted: 1400
# Number of cars inserted: 1500
# Number of cars inserted: 1600
# Number of cars inserted: 1700
# Number of cars inserted: 1800
# Number of cars inserted: 1900
# Number of cars inserted: 2000
# Number of cars inserted: 2100
# Number of cars inserted: 2200
# Number of cars inserted: 2300
# Number of cars inserted: 2400
# Number of cars inserted: 2500
# Number of cars inserted: 2600
# Number of cars inserted: 2700
# Number of cars inserted: 2800
# Number of cars inserted: 2900
# Number of cars inserted: 3000
# Number of cars inserted: 3100
# Number of cars inserted: 3200
# Number of cars inserted: 3300
# Number of cars inserted: 3400
# Number of cars inserted: 3500
# Number of cars inserted: 3600
# Number of cars inserted: 3700
# Number of cars inserted: 3800
# Number of cars inserted: 3900
# Number of cars inserted: 4000
# Number of cars inserted: 4100
# Number of cars inserted: 4200
# Number of cars inserted: 4300
# Number of cars inserted: 4400
# Number of cars inserted: 4500
# Number of cars inserted: 4600
# Number of cars inserted: 4700
# Number of cars inserted: 4800
# Number of cars inserted: 4900
# Number of cars inserted: 5000
# Number of cars inserted: 5100
# Number of cars inserted: 5200
# Number of cars inserted: 5300
# Number of cars inserted: 5400
# Number of cars inserted: 5500
# Number of cars inserted: 5600
# Number of cars inserted: 5700
# Number of cars inserted: 5800
# Number of cars inserted: 5900
# Number of cars inserted: 6000
# Number of cars inserted: 6100
# Number of cars inserted: 6200
# Number of cars inserted: 6300
# Number of cars inserted: 6400
# Number of cars inserted: 6500
# Number of cars inserted: 6600
# Number of cars inserted: 6700
# Number of cars inserted: 6800
# Number of cars inserted: 6900
# Number of cars inserted: 7000
# Number of cars inserted: 7100
# Number of cars inserted: 7200
# Number of cars inserted: 7300
# Number of cars inserted: 7400
# Number of cars inserted: 7500
# Number of cars inserted: 7600
# Number of cars inserted: 7700
# Number of cars inserted: 7800
# Number of cars inserted: 7900
# Number of cars inserted: 8000
# Number of cars inserted: 8100
# Number of cars inserted: 8200
# Number of cars inserted: 8300
# Number of cars inserted: 8400
# Number of cars inserted: 8500
# Number of cars inserted: 8600
# Number of cars inserted: 8700
# Number of cars inserted: 8800
# Number of cars inserted: 8900
# Number of cars inserted: 9000
# Number of cars inserted: 9100
# Number of cars inserted: 9200
# Number of cars inserted: 9300
# Number of cars inserted: 9400
# Number of cars inserted: 9500
# Number of cars inserted: 9600
# Number of cars inserted: 9700
# Number of cars inserted: 9800
# Number of cars inserted: 9900
# Number of cars inserted: 10000
# Number of cars inserted: 10100
# Number of cars inserted: 10200
# Number of cars inserted: 10300
# Number of cars inserted: 10400
# Number of cars inserted: 10500
# Number of cars inserted: 10600
# Number of cars inserted: 10700
# Number of cars inserted: 10800
# Number of cars inserted: 10900
# Number of cars inserted: 11000
# Number of cars inserted: 11100
# Number of cars inserted: 11200
# Number of cars inserted: 11300
# Number of cars inserted: 11400
# Number of cars inserted: 11500
# Number of cars inserted: 11600
# Number of cars inserted: 11700
# Number of cars inserted: 11800
# Number of cars inserted: 11900
# Number of cars inserted: 12000
# Number of cars inserted: 12100
# Number of cars inserted: 12200
# Number of cars inserted: 12300
# Number of cars inserted: 12400
# Number of cars inserted: 12500
# Number of cars inserted: 12600
# Number of cars inserted: 12700
# Number of cars inserted: 12800
# Number of cars inserted: 12900
# Number of cars inserted: 13000
# Number of cars inserted: 13100
# Number of cars inserted: 13200
# Number of cars inserted: 13300
# Number of cars inserted: 13400
# Number of cars inserted: 13500
# Number of cars inserted: 13600
# Number of cars inserted: 13700
# Number of cars inserted: 13800
# Number of cars inserted: 13900
# Number of cars inserted: 14000
# Number of cars inserted: 14100
# Number of cars inserted: 14200
# Number of cars inserted: 14300
# Number of cars inserted: 14400
# Number of cars inserted: 14500
# Number of cars inserted: 14600
# Number of cars inserted: 14700
# Number of cars inserted: 14800
# Number of cars inserted: 14900
# Number of cars inserted: 15000
# Number of cars inserted: 15100
# Number of cars inserted: 15200
# Number of cars inserted: 15300
# Number of cars inserted: 15400
# Number of cars inserted: 15500
# Number of cars inserted: 15600
# Number of cars inserted: 15700
# Number of cars inserted: 15800
# Number of cars inserted: 15900
# Number of cars inserted: 16000
# Number of cars inserted: 16100
# Number of cars inserted: 16200
# Number of cars inserted: 16300
# Number of cars inserted: 16400
# Number of cars inserted: 16500
# Number of cars inserted: 16600
# Number of cars inserted: 16700
# Number of cars inserted: 16800
# Number of cars inserted: 16900
# Number of cars inserted: 17000
# Number of cars inserted: 17100
# Number of cars inserted: 17200
# Number of cars inserted: 17300
# Number of cars inserted: 17400
# Number of cars inserted: 17500
# Number of cars inserted: 17600
# Number of cars inserted: 17700
# Number of cars inserted: 17800
# Number of cars inserted: 17900
# Number of cars inserted: 18000
# Number of cars inserted: 18100
# Number of cars inserted: 18200
# Number of cars inserted: 18300
# Number of cars inserted: 18400
# Number of cars inserted: 18500
# Number of cars inserted: 18600
# Number of cars inserted: 18700
# Number of cars inserted: 18800
# Number of cars inserted: 18900
# Number of cars inserted: 19000
# Number of cars inserted: 19100
# Number of cars inserted: 19200
# Number of cars inserted: 19300
# Number of cars inserted: 19400
# Number of cars inserted: 19500
# Number of cars inserted: 19600
# Number of cars inserted: 19700
# Number of cars inserted: 19800
# Number of cars inserted: 19900
# Number of cars inserted: 20000
# Number of cars inserted: 20100
# Number of cars inserted: 20200
# Number of cars inserted: 20300
# Number of cars inserted: 20400
# Number of cars inserted: 20500
# Number of cars inserted: 20600
# Number of cars inserted: 20700
# Number of cars inserted: 20800
# Number of cars inserted: 20900
# Number of cars inserted: 21000
# Number of cars inserted: 21100
# Number of cars inserted: 21200
# Number of cars inserted: 21300
# Number of cars inserted: 21400
# Number of cars inserted: 21500
# Number of cars inserted: 21600
# Number of cars inserted: 21700
# Number of cars inserted: 21800
# Number of cars inserted: 21900
# Number of cars inserted: 22000
# Number of cars inserted: 22100
# Number of cars inserted: 22200
# Number of cars inserted: 22300
# Number of cars inserted: 22400
# Number of cars inserted: 22500
# Number of cars inserted: 22600
# Number of cars inserted: 22700
# Number of cars inserted: 22800
# Number of cars inserted: 22900
# Number of cars inserted: 23000
# Number of cars inserted: 23100
# Number of cars inserted: 23200
# Number of cars inserted: 23300
# Number of cars inserted: 23400
# Number of cars inserted: 23500
# Number of cars inserted: 23600
# Number of cars inserted: 23700
# Number of cars inserted: 23800
# Number of cars inserted: 23900
# Number of cars inserted: 24000
# Number of cars inserted: 24100
# Number of cars inserted: 24200
# Number of cars inserted: 24300
# Number of cars inserted: 24400
# Number of cars inserted: 24500
# Number of cars inserted: 24600
# Number of cars inserted: 24700
# Number of cars inserted: 24800
# Number of cars inserted: 24900
# Number of cars inserted: 25000
# Number of cars inserted: 25100
# Number of cars inserted: 25200
# Number of cars inserted: 25300
# Number of cars inserted: 25400
# Number of cars inserted: 25500
# Number of cars inserted: 25600
# Number of cars inserted: 25700
# Number of cars inserted: 25800
# Number of cars inserted: 25900
# Number of cars inserted: 26000
# Number of cars inserted: 26100
# Number of cars inserted: 26200
# Number of cars inserted: 26300
# Number of cars inserted: 26400
# Number of cars inserted: 26500
# Number of cars inserted: 26600
# Number of cars inserted: 26700
# Number of cars inserted: 26800
# Number of cars inserted: 26900
# Number of cars inserted: 27000
# Number of cars inserted: 27100
# Number of cars inserted: 27200
# Number of cars inserted: 27300
# Number of cars inserted: 27400
# Number of cars inserted: 27500
# Number of cars inserted: 27600
# Number of cars inserted: 27700
# Number of cars inserted: 27800
# Number of cars inserted: 27900
# Number of cars inserted: 28000
# Number of cars inserted: 28100
# Number of cars inserted: 28200
# Number of cars inserted: 28300
# Number of cars inserted: 28400
# Number of cars inserted: 28500
# Number of cars inserted: 28600
# Number of cars inserted: 28700
# Number of cars inserted: 28800
# Number of cars inserted: 28900
# Number of cars inserted: 29000
# Number of cars inserted: 29100
# Number of cars inserted: 29200
# Number of cars inserted: 29300
# Number of cars inserted: 29400
# Number of cars inserted: 29500
# Number of cars inserted: 29600
# Number of cars inserted: 29700
# Number of cars inserted: 29800
# Number of cars inserted: 29900
# Number of cars inserted: 30000
# Number of cars inserted: 30100
# Number of cars inserted: 30200
# Number of cars inserted: 30300
# Number of cars inserted: 30400
# Number of cars inserted: 30500
# Number of cars inserted: 30600
# Number of cars inserted: 30700
# Number of cars inserted: 30800
# Number of cars inserted: 30900
# Number of cars inserted: 31000
# Number of cars inserted: 31100
# Number of cars inserted: 31200
# Number of cars inserted: 31300
# Number of cars inserted: 31400
# Number of cars inserted: 31500
# Number of cars inserted: 31600
# Number of cars inserted: 31700
# Number of cars inserted: 31800
# Number of cars inserted: 31900
# Number of cars inserted: 32000
# Number of cars inserted: 32100
# Number of cars inserted: 32200
# Number of cars inserted: 32300
# Number of cars inserted: 32400
# Number of cars inserted: 32500
# Number of cars inserted: 32600
# Number of cars inserted: 32700
# Number of cars inserted: 32800
# Number of cars inserted: 32900
# Number of cars inserted: 33000
# Number of cars inserted: 33100
# Number of cars inserted: 33200
# Number of cars inserted: 33300
# Number of cars inserted: 33400
# Number of cars inserted: 33500
# Number of cars inserted: 33600
# Number of cars inserted: 33700
# Number of cars inserted: 33800
# Number of cars inserted: 33900
# Number of cars inserted: 34000
# Number of cars inserted: 34100
# Number of cars inserted: 34200
# Number of cars inserted: 34300
# Number of cars inserted: 34400
# Number of cars inserted: 34500
# Number of cars inserted: 34600
# Number of cars inserted: 34700
# Number of cars inserted: 34800
# Number of cars inserted: 34900
# Number of cars inserted: 35000
# Number of cars inserted: 35100
# Number of cars inserted: 35200
# Number of cars inserted: 35300
# Number of cars inserted: 35400
# Number of cars inserted: 35500
# Number of cars inserted: 35600
# Number of cars inserted: 35700
# Number of cars inserted: 35800
# Number of cars inserted: 35900
# Number of cars inserted: 36000
# Number of cars inserted: 36100
# Number of cars inserted: 36200
# Number of cars inserted: 36300
# Number of cars inserted: 36400
# Number of cars inserted: 36500
# Number of cars inserted: 36600
# Number of cars inserted: 36700
# Number of cars inserted: 36800
# Number of cars inserted: 36900
# Number of cars inserted: 37000
# Number of cars inserted: 37100
# Number of cars inserted: 37200
# Number of cars inserted: 37300
# Number of cars inserted: 37400
# Number of cars inserted: 37500
# Number of cars inserted: 37600
# Number of cars inserted: 37700
# Number of cars inserted: 37800
# Number of cars inserted: 37900
# Number of cars inserted: 38000
# Number of cars inserted: 38100
# Number of cars inserted: 38200
# Number of cars inserted: 38300
# Number of cars inserted: 38400
# Number of cars inserted: 38500
# Number of cars inserted: 38600
# Number of cars inserted: 38700
# Number of cars inserted: 38800
# Number of cars inserted: 38900
# Number of cars inserted: 39000
# Number of cars inserted: 39100
# Number of cars inserted: 39200
# Number of cars inserted: 39300
# Number of cars inserted: 39400
# Number of cars inserted: 39500
# Number of cars inserted: 39600
# Number of cars inserted: 39700
# Number of cars inserted: 39800
# Number of cars inserted: 39900
# Number of cars inserted: 40000
# Number of cars inserted: 40100
# Number of cars inserted: 40200
# Number of cars inserted: 40300
# Number of cars inserted: 40400
# Number of cars inserted: 40500
# Number of cars inserted: 40600
# Number of cars inserted: 40700
# Number of cars inserted: 40800
# Number of cars inserted: 40900
# Number of cars inserted: 41000
# Number of cars inserted: 41100
# Number of cars inserted: 41200
# Number of cars inserted: 41300
# Number of cars inserted: 41400
# Number of cars inserted: 41500
# Number of cars inserted: 41600
# Number of cars inserted: 41700
# Number of cars inserted: 41800
# Number of cars inserted: 41900
# Number of cars inserted: 42000
# Number of cars inserted: 42100
# Number of cars inserted: 42200
# Number of cars inserted: 42300
# Number of cars inserted: 42400
# Number of cars inserted: 42500
# Number of cars inserted: 42600
# Number of cars inserted: 42700
# Number of cars inserted: 42800
# Number of cars inserted: 42900
# Number of cars inserted: 43000
# Number of cars inserted: 43100
# Number of cars inserted: 43200
# Number of cars inserted: 43300
# Number of cars inserted: 43400
# Number of cars inserted: 43500
# Number of cars inserted: 43600
# Number of cars inserted: 43700
# Number of cars inserted: 43800
# Number of cars inserted: 43900
# Number of cars inserted: 44000
# Number of cars inserted: 44100
# Number of cars inserted: 44200
# Number of cars inserted: 44300
# Number of cars inserted: 44400
# Number of cars inserted: 44500
# Number of cars inserted: 44600
# Number of cars inserted: 44700
# Number of cars inserted: 44800
# Number of cars inserted: 44900
# Number of cars inserted: 45000
# Number of cars inserted: 45100
# Number of cars inserted: 45200
# Number of cars inserted: 45300
# Number of cars inserted: 45400
# Number of cars inserted: 45500
# Number of cars inserted: 45600
# Number of cars inserted: 45700
# Number of cars inserted: 45800
# Number of cars inserted: 45900
# Number of cars inserted: 46000
# Number of cars inserted: 46100
# Number of cars inserted: 46200
# Number of cars inserted: 46300
# Number of cars inserted: 46400
# Number of cars inserted: 46500
# Number of cars inserted: 46600
# Number of cars inserted: 46700
# Number of cars inserted: 46800
# Number of cars inserted: 46900
# Number of cars inserted: 47000
# Number of cars inserted: 47100
# Number of cars inserted: 47200
# Number of cars inserted: 47300
# Number of cars inserted: 47400
# Number of cars inserted: 47500
# Number of cars inserted: 47600
# Number of cars inserted: 47700
# Number of cars inserted: 47800
# Number of cars inserted: 47900
# Number of cars inserted: 48000
# Number of cars inserted: 48100
# Number of cars inserted: 48200
# Number of cars inserted: 48300
# Number of cars inserted: 48400
# Number of cars inserted: 48500
# Number of cars inserted: 48600
# Number of cars inserted: 48700
# Number of cars inserted: 48800
# Number of cars inserted: 48900
# Number of cars inserted: 49000
# Number of cars inserted: 49100
# Number of cars inserted: 49200
# Number of cars inserted: 49300
# Number of cars inserted: 49400
# Number of cars inserted: 49500
# Number of cars inserted: 49600
# Number of cars inserted: 49700
# Number of cars inserted: 49800
# Number of cars inserted: 49900
# Number of cars inserted: 50000
# Number of cars inserted: 50100
# Number of cars inserted: 50200
# Number of cars inserted: 50300
# Number of cars inserted: 50400
# Number of cars inserted: 50500
# Number of cars inserted: 50600
# Number of cars inserted: 50700
# Number of cars inserted: 50800
# Number of cars inserted: 50900
# Number of cars inserted: 51000
# Number of cars inserted: 51100
# Number of cars inserted: 51200
# Number of cars inserted: 51300
# Number of cars inserted: 51400
# Number of cars inserted: 51500
# Number of cars inserted: 51600
# Number of cars inserted: 51700
# Number of cars inserted: 51800
# Number of cars inserted: 51900
# Number of cars inserted: 52000
# Number of cars inserted: 52100
# Number of cars inserted: 52200
# Number of cars inserted: 52300
# Number of cars inserted: 52400
# Number of cars inserted: 52500
# Number of cars inserted: 52600
# Number of cars inserted: 52700
# Number of cars inserted: 52800
# Number of cars inserted: 52900
# Number of cars inserted: 53000
# Number of cars inserted: 53100
# Number of cars inserted: 53200
# Number of cars inserted: 53300
# Number of cars inserted: 53400
# Number of cars inserted: 53500
# Number of cars inserted: 53600
# Number of cars inserted: 53700
# Number of cars inserted: 53800
# Number of cars inserted: 53900
# Number of cars inserted: 54000
# Number of cars inserted: 54100
# Number of cars inserted: 54200
# Number of cars inserted: 54300
# Number of cars inserted: 54400
# Number of cars inserted: 54500
# Number of cars inserted: 54600
# Number of cars inserted: 54700
# Number of cars inserted: 54800
# Number of cars inserted: 54900
# Number of cars inserted: 55000
# Number of cars inserted: 55100
# Number of cars inserted: 55200
# Number of cars inserted: 55300
# Number of cars inserted: 55400
# Number of cars inserted: 55500
# Number of cars inserted: 55600
# Number of cars inserted: 55700
# Number of cars inserted: 55800
# Number of cars inserted: 55900
# Number of cars inserted: 56000
# Number of cars inserted: 56100
# Number of cars inserted: 56200
# Number of cars inserted: 56300
# Number of cars inserted: 56400
# Number of cars inserted: 56500
# Number of cars inserted: 56600
# Number of cars inserted: 56700
# Number of cars inserted: 56800
# Number of cars inserted: 56900
# Number of cars inserted: 57000
# Number of cars inserted: 57100
# Number of cars inserted: 57200
# Number of cars inserted: 57300
# Number of cars inserted: 57400
# Number of cars inserted: 57500
# Number of cars inserted: 57600
# Number of cars inserted: 57700
# Number of cars inserted: 57800
# Number of cars inserted: 57900
# Number of cars inserted: 58000
# Number of cars inserted: 58100
# Number of cars inserted: 58200
# Number of cars inserted: 58300
# Number of cars inserted: 58400
# Number of cars inserted: 58500
# Number of cars inserted: 58600
# Number of cars inserted: 58700
# Number of cars inserted: 58800
# Number of cars inserted: 58900
# Number of cars inserted: 59000
# Number of cars inserted: 59100
# Number of cars inserted: 59200
# Number of cars inserted: 59300
# Number of cars inserted: 59400
# Number of cars inserted: 59500
# Number of cars inserted: 59600
# Number of cars inserted: 59700
# Number of cars inserted: 59800
# Number of cars inserted: 59900
# Number of cars inserted: 60000
# Number of cars inserted: 60100
# Number of cars inserted: 60200
# Number of cars inserted: 60300
# Number of cars inserted: 60400
# Number of cars inserted: 60500
# Number of cars inserted: 60600
# Number of cars inserted: 60700
# Number of cars inserted: 60800
# Number of cars inserted: 60900
# Number of cars inserted: 61000
# Number of cars inserted: 61100
# Number of cars inserted: 61200
# Number of cars inserted: 61300
# Number of cars inserted: 61400
# Number of cars inserted: 61500
# Number of cars inserted: 61600
# Number of cars inserted: 61700
# Number of cars inserted: 61800
# Number of cars inserted: 61900
# Number of cars inserted: 62000
# Number of cars inserted: 62100
# Number of cars inserted: 62200
# Number of cars inserted: 62300
# Number of cars inserted: 62400
# Number of cars inserted: 62500
# Number of cars inserted: 62600
# Number of cars inserted: 62700
# Number of cars inserted: 62800
# Number of cars inserted: 62900
# Number of cars inserted: 63000
# Number of cars inserted: 63100
# Number of cars inserted: 63200
# Number of cars inserted: 63300
# Number of cars inserted: 63400
# Number of cars inserted: 63500
# Number of cars inserted: 63600
# Number of cars inserted: 63700
# Number of cars inserted: 63800
# Number of cars inserted: 63900
# Number of cars inserted: 64000
# Number of cars inserted: 64100
# Number of cars inserted: 64200
# Number of cars inserted: 64300
# Number of cars inserted: 64400
# Number of cars inserted: 64500
# Number of cars inserted: 64600
# Number of cars inserted: 64700
# Number of cars inserted: 64800
# Number of cars inserted: 64900
# Number of cars inserted: 65000
# Number of cars inserted: 65100
# Number of cars inserted: 65200
# Number of cars inserted: 65300
# Number of cars inserted: 65400
# Number of cars inserted: 65500
# Number of cars inserted: 65600
# Number of cars inserted: 65700
# Number of cars inserted: 65800
# Number of cars inserted: 65900
# Number of cars inserted: 66000
# Number of cars inserted: 66100
# Number of cars inserted: 66200
# Number of cars inserted: 66300
# Number of cars inserted: 66400
# Number of cars inserted: 66500
# Number of cars inserted: 66600
# Number of cars inserted: 66700
# Number of cars inserted: 66800
# Number of cars inserted: 66900
# Number of cars inserted: 67000
# Number of cars inserted: 67100
# Number of cars inserted: 67200
# Number of cars inserted: 67300
# Number of cars inserted: 67400
# Number of cars inserted: 67500
# Number of cars inserted: 67600
# Number of cars inserted: 67700
# Number of cars inserted: 67800
# Number of cars inserted: 67900
# Number of cars inserted: 68000
# Number of cars inserted: 68100
# Number of cars inserted: 68200
# Number of cars inserted: 68300
# Number of cars inserted: 68400
# Number of cars inserted: 68500
# Number of cars inserted: 68600
# Number of cars inserted: 68700
# Number of cars inserted: 68800
# Number of cars inserted: 68900
# Number of cars inserted: 69000
# Number of cars inserted: 69100
# Number of cars inserted: 69200
# Number of cars inserted: 69300
# Number of cars inserted: 69400
# Number of cars inserted: 69500
# Number of cars inserted: 69600
# Number of cars inserted: 69700
# Number of cars inserted: 69800
# Number of cars inserted: 69900
# Number of cars inserted: 70000
# Number of cars inserted: 70100
# Number of cars inserted: 70200
# Number of cars inserted: 70300
# Number of cars inserted: 70400
# Number of cars inserted: 70500
# Number of cars inserted: 70600
# Number of cars inserted: 70700
# Number of cars inserted: 70800
# Number of cars inserted: 70900
# Number of cars inserted: 71000
# Number of cars inserted: 71100
# Number of cars inserted: 71200
# Number of cars inserted: 71300
# Number of cars inserted: 71400
# Number of cars inserted: 71500
# Number of cars inserted: 71600
# Number of cars inserted: 71700
# Number of cars inserted: 71800
# Number of cars inserted: 71900
# Number of cars inserted: 72000
# Number of cars inserted: 72100
# Number of cars inserted: 72200
# Number of cars inserted: 72300
# Number of cars inserted: 72400
# Number of cars inserted: 72500
# Number of cars inserted: 72600
# Number of cars inserted: 72700
# Number of cars inserted: 72800
# Number of cars inserted: 72900
# Number of cars inserted: 73000
# Number of cars inserted: 73100
# Number of cars inserted: 73200
# Number of cars inserted: 73300
# Number of cars inserted: 73400
# Number of cars inserted: 73500
# Number of cars inserted: 73600
# Number of cars inserted: 73700
# Number of cars inserted: 73800
# Number of cars inserted: 73900
# Number of cars inserted: 74000
# Number of cars inserted: 74100
# Number of cars inserted: 74200
# Number of cars inserted: 74300
# Number of cars inserted: 74400
# Number of cars inserted: 74500
# Number of cars inserted: 74600
# Number of cars inserted: 74700
# Number of cars inserted: 74800
# Number of cars inserted: 74900
# Number of cars inserted: 75000
# Number of cars inserted: 75100
# Number of cars inserted: 75200
# Number of cars inserted: 75300
# Number of cars inserted: 75400
# Number of cars inserted: 75500
# Number of cars inserted: 75600
# Number of cars inserted: 75700
# Number of cars inserted: 75800
# Number of cars inserted: 75900
# Number of cars inserted: 76000
# Number of cars inserted: 76100
# Number of cars inserted: 76200
# Number of cars inserted: 76300
# Number of cars inserted: 76400
# Number of cars inserted: 76500
# Number of cars inserted: 76600
# Number of cars inserted: 76700
# Number of cars inserted: 76800
# Number of cars inserted: 76900
# Number of cars inserted: 77000
# Number of cars inserted: 77100
# Number of cars inserted: 77200
# Number of cars inserted: 77300
# Number of cars inserted: 77400
# Number of cars inserted: 77500
# Number of cars inserted: 77600
# Number of cars inserted: 77700
# Number of cars inserted: 77800
# Number of cars inserted: 77900
# Number of cars inserted: 78000
# Number of cars inserted: 78100
# Number of cars inserted: 78200
# Number of cars inserted: 78300
# Number of cars inserted: 78400
# Number of cars inserted: 78500
# Number of cars inserted: 78600
# Number of cars inserted: 78700
# Number of cars inserted: 78800
# Number of cars inserted: 78900
# Number of cars inserted: 79000
# Number of cars inserted: 79100
# Number of cars inserted: 79200
# Number of cars inserted: 79300
# Number of cars inserted: 79400
# Number of cars inserted: 79500
# Number of cars inserted: 79600
# Number of cars inserted: 79700
# Number of cars inserted: 79800
# Number of cars inserted: 79900
# Number of cars inserted: 80000
# Number of cars inserted: 80100
# Number of cars inserted: 80200
# Number of cars inserted: 80300
# Number of cars inserted: 80400
# Number of cars inserted: 80500
# Number of cars inserted: 80600
# Number of cars inserted: 80700
# Number of cars inserted: 80800
# Number of cars inserted: 80900
# Number of cars inserted: 81000
# Number of cars inserted: 81100
# Number of cars inserted: 81200
# Number of cars inserted: 81300
# Number of cars inserted: 81400
# Number of cars inserted: 81500
# Number of cars inserted: 81600
# Number of cars inserted: 81700
# Number of cars inserted: 81800
# Number of cars inserted: 81900
# Number of cars inserted: 82000
# Number of cars inserted: 82100
# Number of cars inserted: 82200
# Number of cars inserted: 82300
# Number of cars inserted: 82400
# Number of cars inserted: 82500
# Number of cars inserted: 82600
# Number of cars inserted: 82700
# Number of cars inserted: 82800
# Number of cars inserted: 82900
# Number of cars inserted: 83000
# Number of cars inserted: 83100
# Number of cars inserted: 83200
# Number of cars inserted: 83300
# Number of cars inserted: 83400
# Number of cars inserted: 83500
# Number of cars inserted: 83600
# Number of cars inserted: 83700
# Number of cars inserted: 83800
# Number of cars inserted: 83900
# Number of cars inserted: 84000
# Number of cars inserted: 84100
# Number of cars inserted: 84200
# Number of cars inserted: 84300
# Number of cars inserted: 84400
# Number of cars inserted: 84500
# Number of cars inserted: 84600
# Number of cars inserted: 84700
# Number of cars inserted: 84800
# Number of cars inserted: 84900
# Number of cars inserted: 85000
# Number of cars inserted: 85100
# Number of cars inserted: 85200
# Number of cars inserted: 85300
# Number of cars inserted: 85400
# Number of cars inserted: 85500
# Number of cars inserted: 85600
# Number of cars inserted: 85700
# Number of cars inserted: 85800
# Number of cars inserted: 85900
# Number of cars inserted: 86000
# Number of cars inserted: 86100
# Number of cars inserted: 86200
# Number of cars inserted: 86300
# Number of cars inserted: 86400
# Number of cars inserted: 86500
# Number of cars inserted: 86600
# Number of cars inserted: 86700
# Number of cars inserted: 86800
# Number of cars inserted: 86900
# Number of cars inserted: 87000
# Number of cars inserted: 87100
# Number of cars inserted: 87200
# Number of cars inserted: 87300
# Number of cars inserted: 87400
# Number of cars inserted: 87500
# Number of cars inserted: 87600
# Number of cars inserted: 87700
# Number of cars inserted: 87800
# Number of cars inserted: 87900
# Number of cars inserted: 88000
# Number of cars inserted: 88100
# Number of cars inserted: 88200
# Number of cars inserted: 88300
# Number of cars inserted: 88400
# Number of cars inserted: 88500
# Number of cars inserted: 88600
# Number of cars inserted: 88700
# Number of cars inserted: 88800
# Number of cars inserted: 88900
# Number of cars inserted: 89000
# Number of cars inserted: 89100
# Number of cars inserted: 89200
# Number of cars inserted: 89300
# Number of cars inserted: 89400
# Number of cars inserted: 89500
# Number of cars inserted: 89600
# Number of cars inserted: 89700
# Number of cars inserted: 89800
# Number of cars inserted: 89900
# Number of cars inserted: 90000
# Number of cars inserted: 90100
# Number of cars inserted: 90200
# Number of cars inserted: 90300
# Number of cars inserted: 90400
# Number of cars inserted: 90500
# Number of cars inserted: 90600
# Number of cars inserted: 90700
# Number of cars inserted: 90800
# Number of cars inserted: 90900
# Number of cars inserted: 91000
# Number of cars inserted: 91100
# Number of cars inserted: 91200
# Number of cars inserted: 91300
# Number of cars inserted: 91400
# Number of cars inserted: 91500
# Number of cars inserted: 91600
# Number of cars inserted: 91700
# Number of cars inserted: 91800
# Number of cars inserted: 91900
# Number of cars inserted: 92000
# Number of cars inserted: 92100
# Number of cars inserted: 92200
# Number of cars inserted: 92300
# Number of cars inserted: 92400
# Number of cars inserted: 92500
# Number of cars inserted: 92600
# Number of cars inserted: 92700
# Number of cars inserted: 92800
# Number of cars inserted: 92900
# Number of cars inserted: 93000
# Number of cars inserted: 93100
# Number of cars inserted: 93200
# Number of cars inserted: 93300
# Number of cars inserted: 93400
# Number of cars inserted: 93500
# Number of cars inserted: 93600
# Number of cars inserted: 93700
# Number of cars inserted: 93800
# Number of cars inserted: 93900
# Number of cars inserted: 94000
# Number of cars inserted: 94100
# Number of cars inserted: 94200
# Number of cars inserted: 94300
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[85], line 27
#      25 car["_id"] = car["idx"]
#      26 car.pop("idx")
# ---> 27 collection.insert_one(car)
#      28 if i % 100 == 0:
#      29     print(f"Number of cars inserted: {i}")
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)
#     826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\mongo_client.py:1898, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    1884 """Execute an operation with consecutive retries if possible
#    1885
#    1886 Returns func()'s return value on success. On error retries the same
#    (...)
#    1895 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    1896 """
#    1897 with self._tmp_session(session) as s:
# -> 1898     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\mongo_client.py:1784, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1779 # Ensure that the options supports retry_writes and there is a valid session not in
#    1780 # transaction, otherwise, we will not support retry behavior for this txn.
#    1781 retryable = bool(
#    1782     retryable and self.options.retry_writes and session and not session.in_transaction
#    1783 )
# -> 1784 return self._retry_internal(
#    1785     func=func,
#    1786     session=session,
#    1787     bulk=bulk,
#    1788     operation=operation,
#    1789     retryable=retryable,
#    1790     operation_id=operation_id,
#    1791 )
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\_csot.py:119, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     117         with _TimeoutContext(timeout):
#     118             return func(self, *args, **kwargs)
# --> 119 return func(self, *args, **kwargs)
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\mongo_client.py:1830, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1793 @_csot.apply
#    1794 def _retry_internal(
#    1795     self,
#    (...)
#    1804     operation_id: Optional[int] = None,
#    1805 ) -> T:
#    1806     """Internal retryable helper for all client transactions.
#    1807
#    1808     :param func: Callback function we want to retry
#    (...)
#    1817     :return: Output of the calling func()
#    1818     """
#    1819     return _ClientConnectionRetryable(
#    1820         mongo_client=self,
#    1821         func=func,
#    1822         bulk=bulk,
#    1823         operation=operation,
#    1824         is_read=is_read,
#    1825         session=session,
#    1826         read_pref=read_pref,
#    1827         address=address,
#    1828         retryable=retryable,
#    1829         operation_id=operation_id,
# -> 1830     ).run()
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\mongo_client.py:2554, in _ClientConnectionRetryable.run(self)
#    2552 self._check_last_error(check_csot=True)
#    2553 try:
# -> 2554     return self._read() if self._is_read else self._write()
#    2555 except ServerSelectionTimeoutError:
#    2556     # The application may think the write was never attempted
#    2557     # if we raise ServerSelectionTimeoutError on the retry
#    2558     # attempt. Raise the original exception instead.
#    2559     self._check_last_error()
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\mongo_client.py:2676, in _ClientConnectionRetryable._write(self)
#    2674             self._check_last_error()
#    2675             self._retryable = False
# -> 2676         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2677 except PyMongoError as exc:
#    2678     if not self._retryable:
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\collection.py:819, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     816 if bypass_doc_val:
#     817     command["bypassDocumentValidation"] = True
# --> 819 result = conn.command(
#     820     self._database.name,
#     821     command,
#     822     write_concern=write_concern,
#     823     codec_options=self._write_response_codec_options,
#     824     session=session,
#     825     client=self._database.client,
#     826     retryable_write=retryable_write,
#     827 )
#     829 _check_write_command_response(result)
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\helpers.py:45, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      42 from pymongo.synchronous.pool import Connection
#      44 try:
# ---> 45     return func(*args, **kwargs)
#      46 except OperationFailure as exc:
#      47     if no_reauth:
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\pool.py:538, in Connection.command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     536     self._raise_if_not_writable(unacknowledged)
#     537 try:
# --> 538     return command(
#     539         self,
#     540         dbname,
#     541         spec,
#     542         self.is_mongos,
#     543         read_preference,
#     544         codec_options,
#     545         session,
#     546         client,
#     547         check,
#     548         allowable_errors,
#     549         self.address,
#     550         listeners,
#     551         self.max_bson_size,
#     552         read_concern,
#     553         parse_write_concern_error=parse_write_concern_error,
#     554         collation=collation,
#     555         compression_ctx=self.compression_context,
#     556         use_op_msg=self.op_msg_enabled,
#     557         unacknowledged=unacknowledged,
#     558         user_fields=user_fields,
#     559         exhaust_allowed=exhaust_allowed,
#     560         write_concern=write_concern,
#     561     )
#     562 except (OperationFailure, NotPrimaryError):
#     563     raise
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\synchronous\network.py:218, in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     216             client._process_response(response_doc, session)
#     217         if check:
# --> 218             helpers_shared._check_command_response(
#     219                 response_doc,
#     220                 conn.max_wire_version,
#     221                 allowable_errors,
#     222                 parse_write_concern_error=parse_write_concern_error,
#     223             )
#     224 except Exception as exc:
#     225     duration = datetime.datetime.now() - start
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pymongo\helpers_shared.py:247, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     244 elif code == 43:
#     245     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 247 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: you are over your space quota, using 512 MB of 512 MB, full error: {'ok': 0, 'errmsg': 'you are over your space quota, using 512 MB of 512 MB', 'code': 8000, 'codeName': 'AtlasError'}
