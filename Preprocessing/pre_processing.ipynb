# %%
import re
import os
import json
import pprint
import pandas as pd

# %%
folder_path = '../dataRAW'
cars = []

for filename in os.listdir(folder_path):
    #print("Procesando archivo: ", filename)
    if filename.endswith('.json'):
        file_path = os.path.join(folder_path, filename)
        with open(file_path, 'r', encoding='utf-8') as f:
            try:
                data = json.load(f)
                #print(f'Hay {len(data)} coches')
                cars.extend(data)
            except json.JSONDecodeError as e:
                print(f"Error al procesar {filename}: {e}")

print(f'ARCHIVOS PROCESADOS: {len(os.listdir(folder_path))} TOTAL: {len(cars)}')
# Out:
# ARCHIVOS PROCESADOS: 1000 TOTAL: 196917

# %%
def extract_word(pattern, text, default_value = None):
    data = re.search(pattern, text)
    if data != None: return data.group(1)
    else: return default_value

def exist_word(word, text): return (word in text)

def flatten_dict(d, parent_key='', sep='.'):
    """
    Aplana un diccionario anidado, pero deja las listas sin aplanar.
    :param d: Diccionario a aplanar.
    :param parent_key: Clave padre para formar claves compuestas.
    :param sep: Separador entre claves (por defecto es un punto '.').
    :return: Diccionario aplanado.
    """
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            # Llamada recursiva para diccionarios anidados
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            # Mantener las listas sin aplanar
            items.append((new_key, v))
        else:
            # Caso base: clave simple con un valor
            items.append((new_key, v))
    return dict(items)

def extract_phrase (pattern, text, group_index = 1, default_value = None):
    data = re.search(pattern, text)
    if data != None: return data.group(group_index).strip()
    else: return default_value

def extract_list_phrases (car, keyWord, categorie):
    ret = []
    for phrase in car[categorie]:
        if(keyWord in phrase):
            ret.append(phrase)
    return ret

'''
Traducción de las claves:
traccion → traction
frenos → brakes
suspension_delantera → front_suspension
suspension_trasera → rear_suspension
potencia_cv → power_cv
potencia_kw → power_kw
rpm_potencia_max → rpm_max_power
par_maximo_nm → max_torque_nm
rpm_par_max → rpm_max_torque
motor_description → motor_description
transmission_description → transmission_description
'''
def process_technical_details(car):

    if "Ficha Técnica" in car:
        text = "#".join(car["Ficha Técnica"])

        car["jato_classification"] = extract_word(r'clasificación JATO: .*?(\w+\d+)', text)
        car["traction"] = extract_word(r'Tracción\s+(\w+)', text)
        car["brakes"] = extract_phrase(r'[^#]*frenos[^#]*', text, 0)
        car["front_suspension"] = extract_phrase(r'Suspensión delantera([^,]*)', text)
        car["rear_suspension"] = extract_phrase(r'suspensión trasera([^#]*)', text)
        car["power_cv"] = extract_word(r'(\d+)\s*CV', text)
        car["power_kw"] = extract_word(r'(\d+)\s*kW', text)
        car["rpm_max_power"] = extract_word(r'([\d.,]+)\s*rpm\s*\(potencia max\)', text)
        car["max_torque_nm"] = extract_word(r'(\d+)\s*Nm', text)
        car["rpm_max_torque"] = extract_word(r'([\d.,]+)\s*rpm\s*\(par max\)', text)
        car["motor_description"] = extract_phrase(r'Motor de[^#]*', text, 0)
        car["transmission_description"] = extract_phrase(r'Transmisión de tipo[^#]*', text, 0)
        car.pop("Ficha Técnica")
    else:
        car["jato_classification"] = None
        car["traction"] = None
        car["brakes"] = None
        car["front_suspension"] = None
        car["rear_suspension"] = None
        car["power_cv"] = None
        car["power_kw"] = None
        car["rpm_max_power"] = None
        car["max_torque_nm"] = None
        car["rpm_max_torque"] = None
        car["motor_description"] = None
        car["transmission_description"] = None
    return car

'''
bodyType None = Undetermined (can be anyone)
bodyType 1 = Berlina
bodyType 2 = Coupe
bodyType 3 = Cabrio
bodyType 4 = Familiar
bodyType 5 = Monovolumen
bodyType 6 = SUV
bodyType 7 = Pick Up
bodyType 8 = Furgoneta
'''
def assign_body_type(car):
    body_type_id = car.get("bodyTypeId", None)
    match body_type_id:
        case None: car["bodyTypeId"] = None
        case 1: car["bodyTypeId"] = "Berlina"
        case 2: car["bodyTypeId"] = "Coupe"
        case 3: car["bodyTypeId"] = "Cabrio"
        case 4: car["bodyTypeId"] = "Familiar" 
        case 5: car["bodyTypeId"] = "Monovolumen"
        case 6: car["bodyTypeId"] = "SUV"
        case 7: car["bodyTypeId"] = "Pick Up"
        case 8: car["bodyTypeId"] = "Furgoneta"
    return car

def process_audio(car):
    # We will reduce the performance from having to not having, specifications like the screen size 
    # have so little variation that it is negligible from 6.5 to 7 inches, and it is assumed that if there is a trip computer, 
    # there will obviously be a touchscreen display; the opposite makes no sense.
    if "Multimedia y Audio" in car:
        text = "#".join(car["Multimedia y Audio"])
        car["speakers"] = extract_word(r'(\w+)\s+altavoces', text, default_value=0)
        car["trip_computer"] = exist_word("Ordenador de viaje", text)
        car["remote_audio_control_on_steering_wheel"] = exist_word("Control remoto de audio", text)
        car["dvd_navigation"] = exist_word("Navegador DVD", text)
        car["antenna"] = exist_word("Antena", text) or exist_word("antena", text) or exist_word("antenas", text) or exist_word("Antenas", text)
        car.pop("Multimedia y Audio")
    else:
        car["speakers"] = None
        car["trip_computer"] = None
        car["remote_audio_control_on_steering_wheel"] = None
        car["dvd_navigation"] = None
        car["antenna"] = None
    return car

def process_segurity(car):
    if "Seguridad" in car:
        text = "#".join(car["Seguridad"])
        car["abs"] = exist_word("ABS", text)  # Anti-Block System
        car["electronic_traction_control"] = exist_word("Control electrónico de tracción", text)
        car["parking_sensors"] = extract_phrase(r'Sensores de aparcamiento[^#]*', text, 0, default_value="No tiene")
        if exist_word("Airbag", text):
            car["airbag"] = extract_list_phrases(car, "Airbag", "Seguridad")
        else:
            car["airbag"] = ["No tiene"]

        car["stability_control"] = exist_word("Control de estabilidad", text)
        car["curve_braking_control"] = exist_word("Control de frenada en curva", text)
        car["isofix_system"] = exist_word("Isofix", text)
        car["start_stop_automatic"] = exist_word("Start/Stop parada y arranque automático", text)
        car.pop("Seguridad")
    else:
        car["abs"] = None
        car["electronic_traction_control"] = None
        car["parking_sensors"] = None
        car["airbag"] = None
        car["stability_control"] = None
        car["curve_braking_control"] = None
        car["isofix_system"] = None
        car["start_stop_automatic"] = None
    return car

def process_dimension(car):
    if "Dimensiones" in car:
        text = "#".join(car["Dimensiones"])
        phrase = extract_phrase(r'Capacidad del compartimento de carga([^,]*)', text)
        if( phrase != None):
            car["cubicCapacity_seat_folded"] = extract_word(r'\by\s+(\d+)', phrase, default_value=car.get("cubicCapacity", 0))
        car.pop("Dimensiones")
    else:
        car["cubicCapacity_seat_folded"] = car.get("cubicCapacity", 0)
    return car

def process_abundant_categories(car, categorie):
    if categorie in car:
        keys = []
        for phrase in car[categorie]:
            str_list = phrase.split(" ")
            if str_list[0] not in keys:
                keys.append(str_list[0])
        
        for key in keys:
            car[categorie+"_"+key] = extract_list_phrases(car, key, categorie)
        car.pop(categorie)
    return car

conforts = []
acabado_int = []
acabado_ext = []

for car in cars:
    if "Confort" in car : conforts = list(set(car["Confort"]) | set(conforts))
    if "Acabado Exterior" in car : acabado_ext = list(set(car["Acabado Exterior"]) | set(acabado_ext))
    if "Acabado Interior" in car : acabado_int = list(set(car["Acabado Interior"]) | set(acabado_int))

    car.update(flatten_dict(car))

    if "electricFeatures" in car : car.pop("electricFeatures")
    if "dimensions" in car : car.pop("dimensions")
    if "consumption" in car : car.pop("consumption")
    
    car = process_technical_details(car)
    car = assign_body_type(car)
    car = process_audio(car)
    car = process_segurity(car)
    car = process_dimension(car)

    car = process_abundant_categories(car, "Confort")
    car = process_abundant_categories(car, "Acabado Exterior")
    car = process_abundant_categories(car, "Acabado Interior")

    if "Información Básica" in car : car.pop("Información Básica")
    if "Prestaciones" in car : car.pop("Prestaciones")

conforts = sorted(list(set(conforts)))
acabado_int = sorted(list(set(acabado_int)))
acabado_ext = sorted(list(set(acabado_ext)))
pprint.pprint(cars[1])
#for x in conforts: x
# Out:
# {'abs': None,
#  'airbag': None,
#  'antenna': None,
#  'bodyTypeId': 'SUV',
#  'brakes': None,
#  'contractId': '1',
#  'creationDate': '2024-09-04T12:41:08Z',
#  'cubicCapacity': 1798,
#  'cubicCapacity_seat_folded': 1798,
#  'curve_braking_control': None,
#  'detail': {'ad': {'category': {'category1Id': 2500,
#                                 'category2Id': 2810,
#                                 'category3Id': 2810},
#                    'creationDate': '2024-09-04T12:41:08+02:00',
#                    'description': 'Incluye garantía de 12 meses.\n'
#                                   '4x4 150cv diesel 2012, extras: '
#                                   'climatizador, bluetooth, baca oficial, '
#                                   'rueda repuesto.\n'
#                                   'vehiculo procedente de direccion de '
#                                   'mitsubishi España comprado en 2013 con '
#                                   '45000km. entrego con todas las facturas de '
#                                   'mantenimiento e itvs.\n'
#                                   'en muy buen estado de conservacion.\n'
#                                   'disponible para ver y probar.\n'
#                                   'No Negociable.',
#                    'externalAdId': '152007458',
#                    'id': '58638307',
#                    'location': {'mainProvinceId': 28, 'provinceIds': [28]},
#                    'offerTypeId': 0,
#                    'offerTypeRevisedId': 1,
#                    'price': {'hasTaxes': False, 'price': 5250, 'taxTypeId': 1},
#                    'privateSeller': {'name': 'Federico',
#                                      'phone': '',
#                                      'provinceId': 28,
#                                      'userId': '6029484'},
#                    'provinceId': 28,
#                    'publicationDate': '2024-10-10T22:29:02+02:00',
#                    'status': 'active',
#                    'title': 'MITSUBISHI ASX 200 DID Motion 4WD 5p.',
#                    'url': '/mitsubishi-asx-200-did-motion-4wd-5p-diesel-2012-en-madrid-58638307-covo.aspx',
#                    'vehicle': {'color': 'Negro',
#                                'colorId': 9,
#                                'hasVehicleHistory': False,
#                                'isCertified': False,
#                                'km': 315000,
#                                'plateRegistrationDate': '11/2012',
#                                'specs': {'bodyTypeId': 6,
#                                          'cubicCapacity': 1798,
#                                          'doors': 5,
#                                          'fuelTypeId': 1,
#                                          'make': 'MITSUBISHI',
#                                          'makeId': 30,
#                                          'model': 'ASX',
#                                          'modelId': 965,
#                                          'power': 150,
#                                          'seatingCapacity': 5,
#                                          'transmissionTypeId': 2,
#                                          'version': '200 DID Motion 4WD',
#                                          'versionId': 44899},
#                                'year': 2012}},
#             'privateSeller': {'avatarUrl': 'https://a.ccdn.es/cnet/usermedia/2021/01/17/6029484/83013.jpg',
#                               'creationDate': '2019-10-15T08:59:09.000+00:00',
#                               'email': '',
#                               'hidePhone': True,
#                               'lastName': 'San Andres ',
#                               'name': 'Federico',
#                               'phone': '',
#                               'provinceId': 28,
#                               'userId': 6029484,
#                               'zipCode': '28050'},
#             'reservation': {'adId': '58638307',
#                             'adReservationStatus': 'non_reservable',
#                             'reservationId': None},
#             'trade': {'isTradable': True},
#             'vehicleHistory': {'hasReport': False,
#                                'reportUrl': 'https://www.carfax.es/partner-coches?vin=&make=MITSUBISHI&model=ASX&pic=https://a.ccdn.es/cnet/2024/09/04/58638307/1953507218_g.jpg'}},
#  'detail.ad.category.category1Id': 2500,
#  'detail.ad.category.category2Id': 2810,
#  'detail.ad.category.category3Id': 2810,
#  'detail.ad.creationDate': '2024-09-04T12:41:08+02:00',
#  'detail.ad.description': 'Incluye garantía de 12 meses.\n'
#                           '4x4 150cv diesel 2012, extras: climatizador, '
#                           'bluetooth, baca oficial, rueda repuesto.\n'
#                           'vehiculo procedente de direccion de mitsubishi '
#                           'España comprado en 2013 con 45000km. entrego con '
#                           'todas las facturas de mantenimiento e itvs.\n'
#                           'en muy buen estado de conservacion.\n'
#                           'disponible para ver y probar.\n'
#                           'No Negociable.',
#  'detail.ad.externalAdId': '152007458',
#  'detail.ad.id': '58638307',
#  'detail.ad.location.mainProvinceId': 28,
#  'detail.ad.location.provinceIds': [28],
#  'detail.ad.offerTypeId': 0,
#  'detail.ad.offerTypeRevisedId': 1,
#  'detail.ad.price.hasTaxes': False,
#  'detail.ad.price.price': 5250,
#  'detail.ad.price.taxTypeId': 1,
#  'detail.ad.privateSeller.name': 'Federico',
#  'detail.ad.privateSeller.phone': '',
#  'detail.ad.privateSeller.provinceId': 28,
#  'detail.ad.privateSeller.userId': '6029484',
#  'detail.ad.provinceId': 28,
#  'detail.ad.publicationDate': '2024-10-10T22:29:02+02:00',
#  'detail.ad.status': 'active',
#  'detail.ad.title': 'MITSUBISHI ASX 200 DID Motion 4WD 5p.',
#  'detail.ad.url': '/mitsubishi-asx-200-did-motion-4wd-5p-diesel-2012-en-madrid-58638307-covo.aspx',
#  'detail.ad.vehicle.color': 'Negro',
#  'detail.ad.vehicle.colorId': 9,
#  'detail.ad.vehicle.hasVehicleHistory': False,
#  'detail.ad.vehicle.isCertified': False,
#  'detail.ad.vehicle.km': 315000,
#  'detail.ad.vehicle.plateRegistrationDate': '11/2012',
#  'detail.ad.vehicle.specs.bodyTypeId': 6,
#  'detail.ad.vehicle.specs.cubicCapacity': 1798,
#  'detail.ad.vehicle.specs.doors': 5,
#  'detail.ad.vehicle.specs.fuelTypeId': 1,
#  'detail.ad.vehicle.specs.make': 'MITSUBISHI',
#  'detail.ad.vehicle.specs.makeId': 30,
#  'detail.ad.vehicle.specs.model': 'ASX',
#  'detail.ad.vehicle.specs.modelId': 965,
#  'detail.ad.vehicle.specs.power': 150,
#  'detail.ad.vehicle.specs.seatingCapacity': 5,
#  'detail.ad.vehicle.specs.transmissionTypeId': 2,
#  'detail.ad.vehicle.specs.version': '200 DID Motion 4WD',
#  'detail.ad.vehicle.specs.versionId': 44899,
#  'detail.ad.vehicle.year': 2012,
#  'detail.privateSeller.avatarUrl': 'https://a.ccdn.es/cnet/usermedia/2021/01/17/6029484/83013.jpg',
#  'detail.privateSeller.creationDate': '2019-10-15T08:59:09.000+00:00',
#  'detail.privateSeller.email': '',
#  'detail.privateSeller.hidePhone': True,
#  'detail.privateSeller.lastName': 'San Andres ',
#  'detail.privateSeller.name': 'Federico',
#  'detail.privateSeller.phone': '',
#  'detail.privateSeller.provinceId': 28,
#  'detail.privateSeller.userId': 6029484,
#  'detail.privateSeller.zipCode': '28050',
#  'detail.reservation.adId': '58638307',
#  'detail.reservation.adReservationStatus': 'non_reservable',
#  'detail.reservation.reservationId': None,
#  'detail.trade.isTradable': True,
#  'detail.vehicleHistory.hasReport': False,
#  'detail.vehicleHistory.reportUrl': 'https://www.carfax.es/partner-coches?vin=&make=MITSUBISHI&model=ASX&pic=https://a.ccdn.es/cnet/2024/09/04/58638307/1953507218_g.jpg',
#  'drivenWheelsId': 1,
#  'dvd_navigation': None,
#  'electronic_traction_control': None,
#  'front_suspension': None,
#  'fuelType': 'Diésel',
#  'fuelTypeId': 1,
#  'hasUrge': False,
#  'id': '58638307',
#  'isCertified': False,
#  'isFinanced': False,
#  'isProfessional': False,
#  'isofix_system': None,
#  'jato_classification': None,
#  'km': 315000,
#  'location': {'cityId': 28800,
#               'cityLiteral': 'La Moraleja',
#               'mainProvince': 'Madrid',
#               'mainProvinceId': 28,
#               'provinceIds': [28]},
#  'location.cityId': 28800,
#  'location.cityLiteral': 'La Moraleja',
#  'location.mainProvince': 'Madrid',
#  'location.mainProvinceId': 28,
#  'location.provinceIds': [28],
#  'mainProvince': 'Madrid',
#  'makeId': 30,
#  'max_torque_nm': None,
#  'modelId': 965,
#  'motor_description': None,
#  'offerType': {'id': 0, 'literal': 'Ocasión'},
#  'offerType.id': 0,
#  'offerType.literal': 'Ocasión',
#  'parking_sensors': None,
#  'phone': '',
#  'power_cv': None,
#  'power_kw': None,
#  'price': {'amount': 5250, 'hasTaxes': True, 'taxTypeId': 1},
#  'price.amount': 5250,
#  'price.hasTaxes': True,
#  'price.taxTypeId': 1,
#  'provinceIds': [28],
#  'publishedDate': '2024-09-04T12:42:24Z',
#  'rear_suspension': None,
#  'remote_audio_control_on_steering_wheel': None,
#  'resources': [{'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507218_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507225_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507220_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507226_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507207_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507221_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507216_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507223_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507209_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507210_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507214_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507222_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507213_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507219_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507227_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507224_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507215_g.jpg'}],
#  'rpm_max_power': None,
#  'rpm_max_torque': None,
#  'seller': {'contractId': '1', 'isProfessional': False, 'name': 'Federico'},
#  'seller.contractId': '1',
#  'seller.isProfessional': False,
#  'seller.name': 'Federico',
#  'speakers': None,
#  'stability_control': None,
#  'start_stop_automatic': None,
#  'title': 'MITSUBISHI ASX 200 DID Motion 4WD 5p.',
#  'traction': None,
#  'transmissionTypeId': 2,
#  'transmission_description': None,
#  'trip_computer': None,
#  'url': '/mitsubishi-asx-200-did-motion-4wd-5p-diesel-2012-en-madrid-58638307-covo.aspx',
#  'year': 2012}

# %%
def get_categories(list):
    keys = []
    for phrase in list:
        str_list = phrase.split(" ")
        if str_list[0] not in keys:
            keys.append(str_list[0])
    return keys

conforts = get_categories(conforts)
acabado_int = get_categories(acabado_int)
acabado_ext = get_categories(acabado_ext)

def completeCategories(car, categories, name):
    for categ in categories:
        if not ((name+"_"+categ) in car):
            if car["hasDetails"]:
                car[name+"_"+categ] = "no tiene"
            else: car[name+"_"+categ] = None
    return car

for car in cars:
    car = completeCategories(car, acabado_int, "Acabado Interior")
    car = completeCategories(car, conforts, "Confort")
    car = completeCategories(car, acabado_ext, "Acabado Exterior")
    
pprint.pprint(cars[1])
# Out:
# {'abs': None,
#  'airbag': None,
#  'antenna': None,
#  'bodyTypeId': 'SUV',
#  'brakes': None,
#  'contractId': '1',
#  'creationDate': '2024-09-04T12:41:08Z',
#  'cubicCapacity': 1798,
#  'cubicCapacity_seat_folded': 1798,
#  'curve_braking_control': None,
#  'detail': {'ad': {'category': {'category1Id': 2500,
#                                 'category2Id': 2810,
#                                 'category3Id': 2810},
#                    'creationDate': '2024-09-04T12:41:08+02:00',
#                    'description': 'Incluye garantía de 12 meses.\n'
#                                   '4x4 150cv diesel 2012, extras: '
#                                   'climatizador, bluetooth, baca oficial, '
#                                   'rueda repuesto.\n'
#                                   'vehiculo procedente de direccion de '
#                                   'mitsubishi España comprado en 2013 con '
#                                   '45000km. entrego con todas las facturas de '
#                                   'mantenimiento e itvs.\n'
#                                   'en muy buen estado de conservacion.\n'
#                                   'disponible para ver y probar.\n'
#                                   'No Negociable.',
#                    'externalAdId': '152007458',
#                    'id': '58638307',
#                    'location': {'mainProvinceId': 28, 'provinceIds': [28]},
#                    'offerTypeId': 0,
#                    'offerTypeRevisedId': 1,
#                    'price': {'hasTaxes': False, 'price': 5250, 'taxTypeId': 1},
#                    'privateSeller': {'name': 'Federico',
#                                      'phone': '',
#                                      'provinceId': 28,
#                                      'userId': '6029484'},
#                    'provinceId': 28,
#                    'publicationDate': '2024-10-10T22:29:02+02:00',
#                    'status': 'active',
#                    'title': 'MITSUBISHI ASX 200 DID Motion 4WD 5p.',
#                    'url': '/mitsubishi-asx-200-did-motion-4wd-5p-diesel-2012-en-madrid-58638307-covo.aspx',
#                    'vehicle': {'color': 'Negro',
#                                'colorId': 9,
#                                'hasVehicleHistory': False,
#                                'isCertified': False,
#                                'km': 315000,
#                                'plateRegistrationDate': '11/2012',
#                                'specs': {'bodyTypeId': 6,
#                                          'cubicCapacity': 1798,
#                                          'doors': 5,
#                                          'fuelTypeId': 1,
#                                          'make': 'MITSUBISHI',
#                                          'makeId': 30,
#                                          'model': 'ASX',
#                                          'modelId': 965,
#                                          'power': 150,
#                                          'seatingCapacity': 5,
#                                          'transmissionTypeId': 2,
#                                          'version': '200 DID Motion 4WD',
#                                          'versionId': 44899},
#                                'year': 2012}},
#             'privateSeller': {'avatarUrl': 'https://a.ccdn.es/cnet/usermedia/2021/01/17/6029484/83013.jpg',
#                               'creationDate': '2019-10-15T08:59:09.000+00:00',
#                               'email': '',
#                               'hidePhone': True,
#                               'lastName': 'San Andres ',
#                               'name': 'Federico',
#                               'phone': '',
#                               'provinceId': 28,
#                               'userId': 6029484,
#                               'zipCode': '28050'},
#             'reservation': {'adId': '58638307',
#                             'adReservationStatus': 'non_reservable',
#                             'reservationId': None},
#             'trade': {'isTradable': True},
#             'vehicleHistory': {'hasReport': False,
#                                'reportUrl': 'https://www.carfax.es/partner-coches?vin=&make=MITSUBISHI&model=ASX&pic=https://a.ccdn.es/cnet/2024/09/04/58638307/1953507218_g.jpg'}},
#  'detail.ad.category.category1Id': 2500,
#  'detail.ad.category.category2Id': 2810,
#  'detail.ad.category.category3Id': 2810,
#  'detail.ad.creationDate': '2024-09-04T12:41:08+02:00',
#  'detail.ad.description': 'Incluye garantía de 12 meses.\n'
#                           '4x4 150cv diesel 2012, extras: climatizador, '
#                           'bluetooth, baca oficial, rueda repuesto.\n'
#                           'vehiculo procedente de direccion de mitsubishi '
#                           'España comprado en 2013 con 45000km. entrego con '
#                           'todas las facturas de mantenimiento e itvs.\n'
#                           'en muy buen estado de conservacion.\n'
#                           'disponible para ver y probar.\n'
#                           'No Negociable.',
#  'detail.ad.externalAdId': '152007458',
#  'detail.ad.id': '58638307',
#  'detail.ad.location.mainProvinceId': 28,
#  'detail.ad.location.provinceIds': [28],
#  'detail.ad.offerTypeId': 0,
#  'detail.ad.offerTypeRevisedId': 1,
#  'detail.ad.price.hasTaxes': False,
#  'detail.ad.price.price': 5250,
#  'detail.ad.price.taxTypeId': 1,
#  'detail.ad.privateSeller.name': 'Federico',
#  'detail.ad.privateSeller.phone': '',
#  'detail.ad.privateSeller.provinceId': 28,
#  'detail.ad.privateSeller.userId': '6029484',
#  'detail.ad.provinceId': 28,
#  'detail.ad.publicationDate': '2024-10-10T22:29:02+02:00',
#  'detail.ad.status': 'active',
#  'detail.ad.title': 'MITSUBISHI ASX 200 DID Motion 4WD 5p.',
#  'detail.ad.url': '/mitsubishi-asx-200-did-motion-4wd-5p-diesel-2012-en-madrid-58638307-covo.aspx',
#  'detail.ad.vehicle.color': 'Negro',
#  'detail.ad.vehicle.colorId': 9,
#  'detail.ad.vehicle.hasVehicleHistory': False,
#  'detail.ad.vehicle.isCertified': False,
#  'detail.ad.vehicle.km': 315000,
#  'detail.ad.vehicle.plateRegistrationDate': '11/2012',
#  'detail.ad.vehicle.specs.bodyTypeId': 6,
#  'detail.ad.vehicle.specs.cubicCapacity': 1798,
#  'detail.ad.vehicle.specs.doors': 5,
#  'detail.ad.vehicle.specs.fuelTypeId': 1,
#  'detail.ad.vehicle.specs.make': 'MITSUBISHI',
#  'detail.ad.vehicle.specs.makeId': 30,
#  'detail.ad.vehicle.specs.model': 'ASX',
#  'detail.ad.vehicle.specs.modelId': 965,
#  'detail.ad.vehicle.specs.power': 150,
#  'detail.ad.vehicle.specs.seatingCapacity': 5,
#  'detail.ad.vehicle.specs.transmissionTypeId': 2,
#  'detail.ad.vehicle.specs.version': '200 DID Motion 4WD',
#  'detail.ad.vehicle.specs.versionId': 44899,
#  'detail.ad.vehicle.year': 2012,
#  'detail.privateSeller.avatarUrl': 'https://a.ccdn.es/cnet/usermedia/2021/01/17/6029484/83013.jpg',
#  'detail.privateSeller.creationDate': '2019-10-15T08:59:09.000+00:00',
#  'detail.privateSeller.email': '',
#  'detail.privateSeller.hidePhone': True,
#  'detail.privateSeller.lastName': 'San Andres ',
#  'detail.privateSeller.name': 'Federico',
#  'detail.privateSeller.phone': '',
#  'detail.privateSeller.provinceId': 28,
#  'detail.privateSeller.userId': 6029484,
#  'detail.privateSeller.zipCode': '28050',
#  'detail.reservation.adId': '58638307',
#  'detail.reservation.adReservationStatus': 'non_reservable',
#  'detail.reservation.reservationId': None,
#  'detail.trade.isTradable': True,
#  'detail.vehicleHistory.hasReport': False,
#  'detail.vehicleHistory.reportUrl': 'https://www.carfax.es/partner-coches?vin=&make=MITSUBISHI&model=ASX&pic=https://a.ccdn.es/cnet/2024/09/04/58638307/1953507218_g.jpg',
#  'drivenWheelsId': 1,
#  'dvd_navigation': None,
#  'electronic_traction_control': None,
#  'front_suspension': None,
#  'fuelType': 'Diésel',
#  'fuelTypeId': 1,
#  'hasUrge': False,
#  'id': '58638307',
#  'isCertified': False,
#  'isFinanced': False,
#  'isProfessional': False,
#  'isofix_system': None,
#  'jato_classification': None,
#  'km': 315000,
#  'location': {'cityId': 28800,
#               'cityLiteral': 'La Moraleja',
#               'mainProvince': 'Madrid',
#               'mainProvinceId': 28,
#               'provinceIds': [28]},
#  'location.cityId': 28800,
#  'location.cityLiteral': 'La Moraleja',
#  'location.mainProvince': 'Madrid',
#  'location.mainProvinceId': 28,
#  'location.provinceIds': [28],
#  'mainProvince': 'Madrid',
#  'makeId': 30,
#  'max_torque_nm': None,
#  'modelId': 965,
#  'motor_description': None,
#  'offerType': {'id': 0, 'literal': 'Ocasión'},
#  'offerType.id': 0,
#  'offerType.literal': 'Ocasión',
#  'parking_sensors': None,
#  'phone': '',
#  'power_cv': None,
#  'power_kw': None,
#  'price': {'amount': 5250, 'hasTaxes': True, 'taxTypeId': 1},
#  'price.amount': 5250,
#  'price.hasTaxes': True,
#  'price.taxTypeId': 1,
#  'provinceIds': [28],
#  'publishedDate': '2024-09-04T12:42:24Z',
#  'rear_suspension': None,
#  'remote_audio_control_on_steering_wheel': None,
#  'resources': [{'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507218_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507225_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507220_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507226_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507207_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507221_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507216_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507223_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507209_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507210_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507214_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507222_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507213_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507219_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507227_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507224_g.jpg'},
#                {'type': 'IMAGE',
#                 'url': 'https://a.ccdn.es/cnet/2024/09/04/58638307/1953507215_g.jpg'}],
#  'rpm_max_power': None,
#  'rpm_max_torque': None,
#  'seller': {'contractId': '1', 'isProfessional': False, 'name': 'Federico'},
#  'seller.contractId': '1',
#  'seller.isProfessional': False,
#  'seller.name': 'Federico',
#  'speakers': None,
#  'stability_control': None,
#  'start_stop_automatic': None,
#  'title': 'MITSUBISHI ASX 200 DID Motion 4WD 5p.',
#  'traction': None,
#  'transmissionTypeId': 2,
#  'transmission_description': None,
#  'trip_computer': None,
#  'url': '/mitsubishi-asx-200-did-motion-4wd-5p-diesel-2012-en-madrid-58638307-covo.aspx',
#  'year': 2012}

# %%
#with open("data_processed/test/json_test_1.json", 'w', encoding='utf-8') as outfile:
    #json.dump(cars, outfile, ensure_ascii=False, indent=4)

max_file_size = 100 * 1024 * 1024

pandas = pd.DataFrame(cars)
pandas.drop_duplicates(subset='id', inplace=True)
pandas_filtered = pandas[pandas["hasDetails"]]
pandas_filtered['idx'] = range(0, len(pandas_filtered))

id_pandas = pandas_filtered[["idx","id", "url", "car_id"]]
print(len(pandas))
print(len(pandas))

pandas_filtered.drop(columns=["id", "url"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hasDetails'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[16], line 8
#       6 pandas = pd.DataFrame(cars)
#       7 pandas.drop_duplicates(subset='id', inplace=True)
# ----> 8 pandas_filtered = pandas[pandas["hasDetails"]]
#       9 pandas_filtered['idx'] = range(0, len(pandas_filtered))
#      11 id_pandas = pandas_filtered[["idx","id", "url", "car_id"]]
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\Barak\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'hasDetails'

# %%
output_folder = "data_processed/csv"
def split_dataframe_to_csv(df, max_file_size, base_filename):
    file_index = 1
    chunk_size = len(df) // 7 
    while chunk_size > 0:
        start_row = 0
        while start_row < len(df):
            end_row = start_row + chunk_size
            chunk = df.iloc[start_row:end_row]
            filename = f"{output_folder}/{base_filename}_part{file_index}.csv"
            chunk.to_csv(filename, index=False)
            if os.path.getsize(filename) > max_file_size:
                chunk_size //= 2
                os.remove(filename)
            else:
                start_row = end_row
                file_index += 1

        if start_row >= len(df):
            break

split_dataframe_to_csv(pandas_filtered, max_file_size, base_filename="test")
id_pandas.to_csv("data_id/Index.csv")
